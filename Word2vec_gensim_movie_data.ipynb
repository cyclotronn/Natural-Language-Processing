# %% [markdown]
# ### Load Gensim Library

# %%
# !pip install gensim
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.6/dist-packages (3.6.0)
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.6/dist-packages (from gensim) (1.12.0)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from gensim) (1.17.4)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.6/dist-packages (from gensim) (1.3.3)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.6/dist-packages (from gensim) (1.9.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.2.1->gensim) (2.21.0)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.2.1->gensim) (1.10.32)
# Requirement already satisfied: boto>=2.32 in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.2.1->gensim) (2.49.0)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.2.1->gensim) (1.24.3)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.2.1->gensim) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.2.1->gensim) (2019.11.28)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.2.1->gensim) (3.0.4)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.6/dist-packages (from boto3->smart-open>=1.2.1->gensim) (0.9.4)
# Requirement already satisfied: botocore<1.14.0,>=1.13.32 in /usr/local/lib/python3.6/dist-packages (from boto3->smart-open>=1.2.1->gensim) (1.13.32)
# Requirement already satisfied: s3transfer<0.3.0,>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from boto3->smart-open>=1.2.1->gensim) (0.2.1)
# Requirement already satisfied: docutils<0.16,>=0.10 in /usr/local/lib/python3.6/dist-packages (from botocore<1.14.0,>=1.13.32->boto3->smart-open>=1.2.1->gensim) (0.15.2)
# Requirement already satisfied: python-dateutil<2.8.1,>=2.1; python_version >= "2.7" in /usr/local/lib/python3.6/dist-packages (from botocore<1.14.0,>=1.13.32->boto3->smart-open>=1.2.1->gensim) (2.6.1)

# %%
import gensim

# %%
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', 
                    level=logging.INFO)

# %%
# !ls
# Out:
# sample_data

# %% [markdown]
# ### Load Text Data
#
# Data can be downloaded from https://www.kaggle.com/c/word2vec-nlp-tutorial/data

# %%
#This is needed only if you have uploaded data to Google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import pandas as pd

#change file path to point to where you have stored the zip file.
df = pd.read_csv('/content/drive/My Drive/classNotes/statisticalNLP/unlabeledTrainData.tsv.zip', header=0, delimiter="\t", quoting=3)

print('Number of examples in Dataset: ', df.shape)
df.head()
# Out:
# Number of examples in Dataset:  (50000, 2)
#           id                                             review
# 0   "9999_0"  "Watching Time Chasers, it obvious that it was...
# 1  "45057_0"  "I saw this film about 20 years ago and rememb...
# 2  "15561_0"  "Minor Spoilers<br /><br />In New York, Joan B...
# 3   "7161_0"  "I went to see this film with a great deal of ...
# 4  "43971_0"  "Yes, I agree with everyone on this site this ...

# %% [markdown]
# ### Function to Clean up data

# %%
import re, string

def clean_str(string):
  """
  String cleaning before vectorization
  """
  try:    
    string = re.sub(r'^https?:\/\/<>.*[\r\n]*', '', string, flags=re.MULTILINE)
    string = re.sub(r"[^A-Za-z]", " ", string)         
    words = string.strip().lower().split()    
    words = [w for w in words if len(w)>=1]
    return " ".join(words)	
  except:
    return ""

# %% [markdown]
# ### Clean the Data using routine above

# %%
df['clean_review'] = df['review'].apply(clean_str)
df.head()
# Out:
#           id  ...                                       clean_review
# 0   "9999_0"  ...  watching time chasers it obvious that it was m...
# 1  "45057_0"  ...  i saw this film about years ago and remember i...
# 2  "15561_0"  ...  minor spoilers br br in new york joan barnard ...
# 3   "7161_0"  ...  i went to see this film with a great deal of e...
# 4  "43971_0"  ...  yes i agree with everyone on this site this mo...
#
# [5 rows x 3 columns]

# %%
df.head()
# Out:
#           id  ...                                       clean_review
# 0   "9999_0"  ...  watching time chasers it obvious that it was m...
# 1  "45057_0"  ...  i saw this film about years ago and remember i...
# 2  "15561_0"  ...  minor spoilers br br in new york joan barnard ...
# 3   "7161_0"  ...  i went to see this film with a great deal of e...
# 4  "43971_0"  ...  yes i agree with everyone on this site this mo...
#
# [5 rows x 3 columns]

# %% [markdown]
# ### Convert Review to a Word List

# %%
#List to hold all words in each review
documents = []

#Iterate over each review
for doc in df['clean_review']:
    documents.append(doc.split(' '))

print(len(documents))
print(documents[0])
# Out:
# 50000
# ['watching', 'time', 'chasers', 'it', 'obvious', 'that', 'it', 'was', 'made', 'by', 'a', 'bunch', 'of', 'friends', 'maybe', 'they', 'were', 'sitting', 'around', 'one', 'day', 'in', 'film', 'school', 'and', 'said', 'hey', 'let', 's', 'pool', 'our', 'money', 'together', 'and', 'make', 'a', 'really', 'bad', 'movie', 'or', 'something', 'like', 'that', 'what', 'ever', 'they', 'said', 'they', 'still', 'ended', 'up', 'making', 'a', 'really', 'bad', 'movie', 'dull', 'story', 'bad', 'script', 'lame', 'acting', 'poor', 'cinematography', 'bottom', 'of', 'the', 'barrel', 'stock', 'music', 'etc', 'all', 'corners', 'were', 'cut', 'except', 'the', 'one', 'that', 'would', 'have', 'prevented', 'this', 'film', 's', 'release', 'life', 's', 'like', 'that']

# %%
len(documents[108])
# Out:
# 121

# %% [markdown]
# ### Build the Model

# %%
#Build the model
model = gensim.models.Word2Vec(documents, #Word list
                               min_count=10, #Ignore all words with total frequency lower than this                           
                               workers=4, #Number of CPU Cores
                               size=50,  #Embedding size
                               window=5, #Maximum Distance between current and predicted word
                               iter=10   #Number of iterations over the text corpus
                              )
# Out:
# 2019-12-07 00:46:02,760 : WARNING : consider setting layer size to a multiple of 4 for greater performance
# 2019-12-07 00:46:02,767 : INFO : collecting all words and their counts
# 2019-12-07 00:46:02,770 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2019-12-07 00:46:03,299 : INFO : PROGRESS: at sentence #10000, processed 2399440 words, keeping 51654 word types
# 2019-12-07 00:46:03,825 : INFO : PROGRESS: at sentence #20000, processed 4835846 words, keeping 69077 word types
# 2019-12-07 00:46:04,385 : INFO : PROGRESS: at sentence #30000, processed 7267977 words, keeping 81515 word types
# 2019-12-07 00:46:04,930 : INFO : PROGRESS: at sentence #40000, processed 9669772 words, keeping 91685 word types
# 2019-12-07 00:46:05,478 : INFO : collected 100479 word types from a corpus of 12084660 raw words and 50000 sentences
# 2019-12-07 00:46:05,479 : INFO : Loading a fresh vocabulary
# 2019-12-07 00:46:06,042 : INFO : effective_min_count=10 retains 28322 unique words (28% of original 100479, drops 72157)
# 2019-12-07 00:46:06,047 : INFO : effective_min_count=10 leaves 11910457 word corpus (98% of original 12084660, drops 174203)
# 2019-12-07 00:46:06,158 : INFO : deleting the raw counts dictionary of 100479 items
# 2019-12-07 00:46:06,167 : INFO : sample=0.001 downsamples 49 most-common words
# 2019-12-07 00:46:06,168 : INFO : downsampling leaves estimated 8817283 word corpus (74.0% of prior 11910457)
# 2019-12-07 00:46:06,298 : INFO : estimated required memory for 28322 words and 50 dimensions: 25489800 bytes
# 2019-12-07 00:46:06,299 : INFO : resetting layer weights
# 2019-12-07 00:46:11,636 : INFO : training model with 4 workers on 28322 vocabulary and 50 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 2019-12-07 00:46:12,658 : INFO : EPOCH 1 - PROGRESS: at 5.67% examples, 495288 words/s, in_qsize 7, out_qsize 0
# 2019-12-07 00:46:13,675 : INFO : EPOCH 1 - PROGRESS: at 11.24% examples, 484564 words/s, in_qsize 5, out_qsize 2
# 2019-12-07 00:46:14,692 : INFO : EPOCH 1 - PROGRESS: at 17.01% examples, 487950 words/s, in_qsize 7, out_qsize 0
# 2019-12-07 00:46:15,733 : INFO : EPOCH 1 - PROGRESS: at 22.73% examples, 485743 words/s, in_qsize 7, out_qsize 0
# 2019-12-07 00:46:16,749 : INFO : EPOCH 1 - PROGRESS: at 28.45% examples, 488775 words/s, in_qsize 6, out_qsize 1
# 2019-12-07 00:46:17,793 : INFO : EPOCH 1 - PROGRESS: at 34.45% examples, 491927 words/s, in_qsize 4, out_qsize 3
# 2019-12-07 00:46:18,796 : INFO : EPOCH 1 - PROGRESS: at 40.13% examples, 494860 words/s, in_qsize 7, out_qsize 0
# 2019-12-07 00:46:19,805 : INFO : EPOCH 1 - PROGRESS: at 45.76% examples, 495176 words/s, in_qsize 7, out_qsize 0
# 2019-12-07 00:46:20,805 : INFO : EPOCH 1 - PROGRESS: at 51.30% examples, 494356 words/s, in_qsize 8, out_qsize 2
# 2019-12-07 00:46:21,809 : INFO : EPOCH 1 - PROGRESS: at 57.22% examples, 497202 words/s, in_qsize 7, out_qsize 0
# 2019-12-07 00:46:22,825 : INFO : EPOCH 1 - PROGRESS: at 62.81% examples, 496938 words/s, in_qsize 7, out_qsize 0
# 2019-12-07 00:46:23,851 : INFO : EPOCH 1 - PROGRESS: at 68.80% examples, 498038 words/s, in_qsize 7, out_qsize 0
# 2019-12-07 00:46
: INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-12-07 00:48:52,066 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-12-07 00:48:52,071 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-12-07 00:48:52,072 : INFO : EPOCH - 9 : training on 12084660 raw words (8815420 effective words) took 17.8s, 495213 effective words/s
# 2019-12-07 00:48:53,128 : INFO : EPOCH 10 - PROGRESS: at 5.60% examples, 469143 words/s, in_qsize 6, out_qsize 1
# 2019-12-07 00:48:54,141 : INFO : EPOCH 10 - PROGRESS: at 11.48% examples, 486881 words/s, in_qsize 6, out_qsize 1
# 2019-12-07 00:48:55,149 : INFO : EPOCH 10 - PROGRESS: at 17.40% examples, 495287 words/s, in_qsize 7, out_qsize 0
# 2019-12-07 00:48:56,153 : INFO : EPOCH 10 - PROGRESS: at 23.14% examples, 495892 words/s, in_qsize 7, out_qsize 0
# 2019-12-07 00:48:57,191 : INFO : EPOCH 10 - PROGRESS: at 28.89% examples, 496115 words/s, in_qsize 7, out_qsize 0
# 2019-12-07 00:48:58,225 : INFO : EPOCH 10 - PROGRESS: at 34.75% examples, 496520 words/s, in_qsize 6, out_qsize 1
# 2019-12-07 00:48:59,230 : INFO : EPOCH 10 - PROGRESS: at 40.38% examples, 497745 words/s, in_qsize 7, out_qsize 0
# 2019-12-07 00:49:00,264 : INFO : EPOCH 10 - PROGRESS: at 46.16% examples, 497838 words/s, in_qsize 7, out_qsize 0
# 2019-12-07 00:49:01,284 : INFO : EPOCH 10 - PROGRESS: at 51.98% examples, 498079 words/s, in_qsize 7, out_qsize 0
# 2019-12-07 00:49:02,290 : INFO : EPOCH 10 - PROGRESS: at 57.64% examples, 498338 words/s, in_qsize 5, out_qsize 2
# 2019-12-07 00:49:03,291 : INFO : EPOCH 10 - PROGRESS: at 62.89% examples, 496126 words/s, in_qsize 7, out_qsize 0
# 2019-12-07 00:49:04,318 : INFO : EPOCH 10 - PROGRESS: at 68.87% examples, 497173 words/s, in_qsize 7, out_qsize 0
# 2019-12-07 00:49:05,338 : INFO : EPOCH 10 - PROGRESS: at 74.66% examples, 497273 words/s, in_qsize 7, out_qsize 0
# 2019-12-07 00:49:06,365 : INFO : EPOCH 10 - PROGRESS: at 80.54% examples, 497072 words/s, in_qsize 6, out_qsize 1
# 2019-12-07 00:49:07,375 : INFO : EPOCH 10 - PROGRESS: at 86.35% examples, 497609 words/s, in_qsize 7, out_qsize 0
# 2019-12-07 00:49:08,385 : INFO : EPOCH 10 - PROGRESS: at 92.01% examples, 497511 words/s, in_qsize 7, out_qsize 0
# 2019-12-07 00:49:09,419 : INFO : EPOCH 10 - PROGRESS: at 97.83% examples, 497525 words/s, in_qsize 7, out_qsize 0
# 2019-12-07 00:49:09,752 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-12-07 00:49:09,758 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-12-07 00:49:09,775 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-12-07 00:49:09,776 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-12-07 00:49:09,777 : INFO : EPOCH - 10 : training on 12084660 raw words (8817478 effective words) took 17.7s, 498100 effective words/s
# 2019-12-07 00:49:09,783 : INFO : training on a 120846600 raw words (88171850 effective words) took 178.1s, 494943 effective words/s

# %% [markdown]
# # Exploring the model

# %% [markdown]
# ### How many words in the model

# %%
#Model size
model.wv.syn0.shape
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `syn0` (Attribute will be removed in 4.0.0, use self.wv.vectors instead).
#   """Entry point for launching an IPython kernel.
# (28322, 50)

# %%
# Vocablury of the model
model.wv.vocab
# Out:
# {'watching': <gensim.models.keyedvectors.Vocab at 0x7f1033fc3278>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x7f1059e1d668>,
#  'chasers': <gensim.models.keyedvectors.Vocab at 0x7f1059e25b70>,
#  'it': <gensim.models.keyedvectors.Vocab at 0x7f100ca6b278>,
#  'obvious': <gensim.models.keyedvectors.Vocab at 0x7f100ca6b198>,
#  'that': <gensim.models.keyedvectors.Vocab at 0x7f100ca6b3c8>,
#  'was': <gensim.models.keyedvectors.Vocab at 0x7f100ca6b2b0>,
#  'made': <gensim.models.keyedvectors.Vocab at 0x7f100ca6b400>,
#  'by': <gensim.models.keyedvectors.Vocab at 0x7f100ca6b240>,
#  'a': <gensim.models.keyedvectors.Vocab at 0x7f100ca6b160>,
#  'bunch': <gensim.models.keyedvectors.Vocab at 0x7f100ca6b1d0>,
#  'of': <gensim.models.keyedvectors.Vocab at 0x7f100ca6b438>,
#  'friends': <gensim.models.keyedvectors.Vocab at 0x7f100ca6b470>,
#  'maybe': <gensim.models.keyedvectors.Vocab at 0x7f100ca6b4a8>,
#  'they': <gensim.models.keyedvectors.Vocab at 0x7f100ca6b4e0>,
#  'were': <gensim.models.keyedvectors.Vocab at 0x7f100ca6b518>,
#  'sitting': <gensim.models.keyedvectors.Vocab at 0x7f100ca6b550>,
#  'around': <gensim.models.keyedvectors.Vocab at 0x7f100ca6b588>,
#  'one': <gensim.models.keyedvectors.Vocab at 0x7f100ca6b5c0>,
#  'day': <gensim.models.keyedvectors.Vocab at 0x7f100ca6b5f8>,
#  'in': <gensim.models.keyedvectors.Vocab at 0x7f100ca6b630>,
#  'film': <gensim.models.keyedvectors.Vocab at 0x7f100ca6b668>,
#  'school': <gensim.models.keyedvectors.Vocab at 0x7f100ca6b6a0>,
#  'and': <gensim.models.keyedvectors.Vocab at 0x7f100ca6b6d8>,
#  'said': <gensim.models.keyedvectors.Vocab at 0x7f100ca6b710>,
#  'hey': <gensim.models.keyedvectors.Vocab at 0x7f100ca6b748>,
#  'let': <gensim.models.keyedvectors.Vocab at 0x7f100ca6b780>,
#  's': <gensim.models.keyedvectors.Vocab at 0x7f100ca6b7b8>,
#  'pool': <gensim.models.keyedvectors.Vocab at 0x7f100ca6b7f0>,
#  'our': <gensim.models.keyedvectors.Vocab at 0x7f100ca6b828>,
#  'money': <gensim.models.keyedvectors.Vocab at 0x7f100ca6b860>,
#  'together': <gensim.models.keyedvectors.Vocab at 0x7f100ca6b898>,
#  'make': <gensim.models.keyedvectors.Vocab at 0x7f100ca6b8d0>,
#  'really': <gensim.models.keyedvectors.Vocab at 0x7f100ca6b908>,
#  'bad': <gensim.models.keyedvectors.Vocab at 0x7f100ca6b940>,
#  'movie': <gensim.models.keyedvectors.Vocab at 0x7f100ca6b978>,
#  'or': <gensim.models.keyedvectors.Vocab at 0x7f100ca6b9b0>,
#  'something': <gensim.models.keyedvectors.Vocab at 0x7f100ca6b9e8>,
#  'like': <gensim.models.keyedvectors.Vocab at 0x7f100ca6ba20>,
#  'what': <gensim.models.keyedvectors.Vocab at 0x7f100ca6ba58>,
#  'ever': <gensim.models.keyedvectors.Vocab at 0x7f100ca6ba90>,
#  'still': <gensim.models.keyedvectors.Vocab at 0x7f100ca6bac8>,
#  'ended': <gensim.models.keyedvectors.Vocab at 0x7f100ca6bb00>,
#  'up': <gensim.models.keyedvectors.Vocab at 0x7f100ca6bb38>,
#  'making': <gensim.models.keyedvectors.Vocab at 0x7f100ca6bb70>,
#  'dull': <gensim.models.keyedvectors.Vocab at 0x7f100ca6bba8>,
#  'story': <gensim.models.keyedvectors.Vocab at 0x7f100ca6bbe0>,
#  'script': <gensim.models.keyedvectors.Vocab at 0x7f100ca6bc18>,
#  'lame': <gensim.models.keyedvectors.Vocab at 0x7f100ca6bc50>,
#  'acting': <gensim.models.keyedvectors.Vocab at 0x7f100ca6bc88>,
#  'poor': <gensim.models.keyedvectors.Vocab at 0x7f100ca6bcc0>,
#  'cinematography': <gensim.models.keyedvectors.Vocab at 0x7f100ca6bcf8>,
#  'bottom': <gensim.models.keyedvectors.Vocab at 0x7f100ca6bd30>,
#  'the': <gensim.models.keyedvectors.Vocab at 0x7f100ca6bd68>,
#  'barrel': <gensim.models.keyedvectors.Vocab at 0x7f100ca6bda0>,
#  'stock': <gensim.models.keyedvectors.Vocab at 0x7f100ca6bdd8>,
#  'music': <gensim.models.keyedvectors.Vocab at 0x7f100ca6be10>,
#  'etc': <gensim.models.keyedvectors.Vocab at 0x7f100ca6be48>,
#  'all': <gensim.models.keyedvectors.Vocab at 0x7f100ca6be80>,
#  'corners': <gensim.models.keyedvectors.Vocab at 0x7f100ca6beb8>,
#  'cut': <gensim.models.keyedvectors.Vocab at 0x7f100ca6bef0>,
#  'except': <gensim.models.keyedvectors.Vocab at 0x7f100ca6bf28>,
#  'would': <gensim.models.keyedvectors.Vocab at 0x7f100ca6bf60>,
#  'have': <gensim.models.keyedvectors.Vocab at 0x7f100ca6bf98>,
#  'prevented': <gensim.models.keyedvectors.Vocab at 0x7f100ca6bfd0>,
#  'this': <gensim.models.keyedvectors.Vocab at 0x7f100ca8a048>,
#  'release': <gensim.models.keyedvectors.Vocab at 0x7f100ca8a080>,
#  'life': <gensim.models.keyedvectors.Vocab at 0x7f100ca8a0b8>,
#  'i': <gensim.models.keyedvectors.Vocab at 0x7f100ca8a0f0>,
#  'saw': <gensim.models.keyedvectors.Vocab at 0x7f100ca8a128>,
#  'about': <gensim.models.keyedvectors.Vocab at 0x7f100ca8a160>,
#  'years': <gensim.models.keyedvectors.Vocab at 0x7f100ca8a198>,
#  'ago': <gensim.models.keyedvectors.Vocab at 0x7f100ca8a1d0>,
#  'remember': <gensim.models.keyedvectors.Vocab at 0x7f100ca8a208>,
#  'as': <gensim.models.keyedvectors.Vocab at 0x7f100ca8a240>,
#  'being': <gensim.models.keyedvectors.Vocab at 0x7f100ca8a278>,
#  'particularly': <gensim.models.keyedvectors.Vocab at 0x7f100ca8a2b0>,
#  'nasty': <gensim.models.keyedvectors.Vocab at 0x7f100ca8a2e8>,
#  'believe': <gensim.models.keyedvectors.Vocab at 0x7f100ca8a320>,
#  'is': <gensim.models.keyedvectors.Vocab at 0x7f100ca8a358>,
#  'based': <gensim.models.keyedvectors.Vocab at 0x7f100ca8a390>,
#  'on': <gensim.models.keyedvectors.Vocab at 0x7f100ca8a3c8>,
#  'true': <gensim.models.keyedvectors.Vocab at 0x7f100ca8a400>,
#  'incident': <gensim.models.keyedvectors.Vocab at 0x7f100ca8a438>,
#  'young': <gensim.models.keyedvectors.Vocab at 0x7f100ca8a470>,
#  'man': <gensim.models.keyedvectors.Vocab at 0x7f100ca8a4a8>,
#  'breaks': <gensim.models.keyedvectors.Vocab at 0x7f100ca8a4e0>,
#  'into': <gensim.models.keyedvectors.Vocab at 0x7f100ca8a518>,
#  'nurses': <gensim.models.keyedvectors.Vocab at 0x7f100ca8a550>,
#  'home': <gensim.models.keyedvectors.Vocab at 0x7f100ca8a588>,
#  'rapes': <gensim.models.keyedvectors.Vocab at 0x7f100ca8a5c0>,
#  'tortures': <gensim.models.keyedvectors.Vocab at 0x7f100ca8a5f8>,
#  'kills': <gensim.models.keyedvectors.Vocab at 0x7f100ca8a630>,
#  'various': <gensim.models.keyedvectors.Vocab at 0x7f100ca8a668>,
#  'women': <gensim.models.keyedvectors.Vocab at 0x7f100ca8a6a0>,
#  'br': <gensim.models.keyedvectors.Vocab at 0x7f100ca8a6d8>,
#  'black': <gensim.models.keyedvectors.Vocab at 0x7f100ca8a710>,
#  'white': <gensim.models.keyedvectors.Vocab at 0x7f100ca8a748>,
#  'but': <gensim.models.keyedvectors.Vocab at 0x7f100ca8a780>,
#  'saves': <gensim.models.keyedvectors.Vocab at 0x7f100ca8a7b8>,
#  'colour': <gensim.models.keyedvectors.Vocab at 0x7f100ca8a7f0>,
#  'for': <gensim.models.keyedvectors.Vocab at 0x7f100ca8a828>,
#  'shocking': <gensim.models.keyedvectors.Vocab at 0x7f100ca8a860>,
#  'shot': <gensim.models.keyedvectors.Vocab at 0x7f100ca8a898>,
#  'at': <gensim.models.keyedvectors.Vocab at 0x7f100ca8a8d0>,
#  'end': <gensim.models.keyedvectors.Vocab at 0x7f100ca8a908>,
#  'seems': <gensim.models.keyedvectors.Vocab at 0x7f100ca8a940>,
#  'to': <gensim.models.keyedvectors.Vocab at 0x7f100ca8a978>,
#  'be': <gensim.models.keyedvectors.Vocab at 0x7f100ca8a9b0>,
#  'trying': <gensim.models.keyedvectors.Vocab at 0x7f100ca8a9e8>,
#  'some': <gensim.models.keyedvectors.Vocab at 0x7f100ca8aa20>,
#  'political': <gensim.models.keyedvectors.Vocab at 0x7f100ca8aa58>,
#  'statement': <gensim.models.keyedvectors.Vocab at 0x7f100ca8aa90>,
#  'just': <gensim.models.keyedvectors.Vocab at 0x7f100ca8aac8>,
#  'comes': <gensim.models.keyedvectors.Vocab at 0x7f100ca8ab00>,
#  'across': <gensim.models.keyedvectors.Vocab at 0x7f100ca8ab38>,
#  'confused': <gensim.models.keyedvectors.Vocab at 0x7f100ca8ab70>,
#  'obscene': <gensim.models.keyedvectors.Vocab at 0x7f100ca8aba8>,
#  'avoid': <gensim.models.keyedvectors.Vocab at 0x7f100ca8abe0>,
#  'minor': <gensim.models.keyedvectors.Vocab at 0x7f100ca8ac18>,
#  'spoilers': <gensim.models.keyedvectors.Vocab at 0x7f100ca8ac50>,
#  'new': <gensim.models.keyedvectors.Vocab at 0x7f100ca8ac88>,
#  'york': <gensim.models.keyedvectors.Vocab at 0x7f100ca8acc0>,
#  'joan': <gensim.models.keyedvectors.Vocab at 0x7f100ca8acf8>,
#  'barnard': <gensim.models.keyedvectors.Vocab at 0x7f100ca8ad30>,
#  'elvire': <gensim.models.keyedvectors.Vocab at 0x7f100ca8ad68>,
#  'audrey': <gensim.models.keyedvectors.Vocab at 0x7f100ca8ada0>,
#  'informed': <gensim.models.keyedvectors.Vocab at 0x7f100ca8add8>,
#  'her': <gensim.models.keyedvectors.Vocab at 0x7f100ca8ae10>,
#  'husband': <gensim.models.keyedvectors.Vocab at 0x7f100ca8ae48>,
#  'arthur': <gensim.models.keyedvectors.Vocab at 0x7f100ca8ae80>,
#  'john': <gensim.models.keyedvectors.Vocab at 0x7f100ca8aeb8>,
#  'saxon': <gensim.models.keyedvectors.Vocab at 0x7f100ca8aef0>,
#  'mysteriously': <gensim.models.keyedvectors.Vocab at 0x7f100ca8af28>,
#  'murdered': <gensim.models.keyedvectors.Vocab at 0x7f100ca8af60>,
#  'italy': <gensim.models.keyedvectors.Vocab at 0x7f100ca8af98>,
#  'while': <gensim.models.keyedvectors.Vocab at 0x7f100ca8afd0>,
#  'searching': <gensim.models.keyedvectors.Vocab at 0x7f100ca8d048>,
#  'an': <gensim.models.keyedvectors.Vocab at 0x7f100ca8d080>,
#  'etruscan': <gensim.models.keyedvectors.Vocab at 0x7f100ca8d0b8>,
#  'tomb': <gensim.models.keyedvectors.Vocab at 0x7f100ca8d0f0>,
#  'decides': <gensim.models.keyedvectors.Vocab at 0x7f100ca8d128>,
#  'travel': <gensim.models.keyedvectors.Vocab at 0x7f100ca8d160>,
#  'company': <gensim.models.keyedvectors.Vocab at 0x7f100ca8d198>,
#  'colleague': <gensim.models.keyedvectors.Vocab at 0x7f100ca8d1d0>,
#  'who': <gensim.models.keyedvectors.Vocab at 0x7f100ca8d208>,
#  'offers': <gensim.models.keyedvectors.Vocab at 0x7f100ca8d240>,
#  'his': <gensim.models.keyedvectors.Vocab at 0x7f100ca8d278>,
#  'support': <gensim.models.keyedvectors.Vocab at 0x7f100ca8d2b0>,
#  'once': <gensim.models.keyedvectors.Vocab at 0x7f100ca8d2e8>,
#  'she': <gensim.models.keyedvectors.Vocab at 0x7f100ca8d320>,
#  'starts': <gensim.models.keyedvectors.Vocab at 0x7f100ca8d358>,
#  'having': <gensim.models.keyedvectors.Vocab at 0x7f100ca8d390>,
#  'visions': <gensim.models.keyedvectors.Vocab at 0x7f100ca8d3c8>,
#  'relative': <gensim.models.keyedvectors.Vocab at 0x7f100ca8d400>,
#  'ancient': <gensim.models.keyedvectors.Vocab at 0x7f100ca8d438>,
#  'people': <gensim.models.keyedvectors.Vocab at 0x7f100ca8d470>,
#  'maggots': <gensim.models.keyedvectors.Vocab at 0x7f100ca8d4a8>,
#  'many': <gensim.models.keyedvectors.Vocab at 0x7f100ca8d4e0>,
#  'after': <gensim.models.keyedvectors.Vocab at 0x7f100ca8d518>,
#  'shootings': <gensim.models.keyedvectors.Vocab at 0x7f100ca8d550>,
#  'weird': <gensim.models.keyedvectors.Vocab at 0x7f100ca8d588>,
#  'events': <gensim.models.keyedvectors.Vocab at 0x7f100ca8d5c0>,
#  'realizes': <gensim.models.keyedvectors.Vocab at 0x7f100ca8d5f8>,
#  'father': <gensim.models.keyedvectors.Vocab at 0x7f100ca8d630>,
#  'international': <gensim.models.keyedvectors.Vocab at 0x7f100ca8d668>,
#  'drug': <gensim.models.keyedvectors.Vocab at 0x7f100ca8d6a0>,
#  'dealer': <gensim.models.keyedvectors.Vocab at 0x7f100ca8d6d8>,
#  'there': <gensim.models.keyedvectors.Vocab at 0x7f100ca8d710>,
#  'are': <gensim.models.keyedvectors.Vocab at 0x7f100ca8d748>,
#  'drugs': <gensim.models.keyedvectors.Vocab at 0x7f100ca8d780>,
#  'hidden': <gensim.models.keyedvectors.Vocab at 0x7f100ca8d7b8>,
#  'detective': <gensim.models.keyedvectors.Vocab at 0x7f100ca8d7f0>,
#  'narcotic': <gensim.models.keyedvectors.Vocab at 0x7f100ca8d828>,
#  'department': <gensim.models.keyedvectors.Vocab at 0x7f100ca8d860>,
#  'ends': <gensim.models.keyedvectors.Vocab at 0x7f100ca8d898>,
#  'back': <gensim.models.keyedvectors.Vocab at 0x7f100ca8d8d0>,
#  'when': <gensim.models.keyedvectors.Vocab at 0x7f100ca8d908>,
#  'decide': <gensim.models.keyedvectors.Vocab at 0x7f100ca8d940>,
#  'get': <gensim.models.keyedvectors.Vocab at 0x7f100ca8d978>,
#  'married': <gensim.models.keyedvectors.Vocab at 0x7f100ca8d9b0>,
#  'with': <gensim.models.keyedvectors.Vocab at 0x7f100ca8d9e8>,
#  'each': <gensim.models.keyedvectors.Vocab at 0x7f100ca8da20>,
#  'other': <gensim.models.keyedvectors.Vocab at 0x7f100ca8da58>,
#  'very': <gensim.models.keyedvectors.Vocab at 0x7f100ca8da90>,
#  'romantic': <gensim.models.keyedvectors.Vocab at 0x7f100ca8dac8>,
#  'yesterday': <gensim.models.keyedvectors.Vocab at 0x7f100ca8db00>,
#  'had': <gensim.models.keyedvectors.Vocab at 0x7f100ca8db38>,
#  'displeasure': <gensim.models.keyedvectors.Vocab at 0x7f100ca8db70>,
#  'wasting': <gensim.models.keyedvectors.Vocab at 0x7f100ca8dba8>,
#  'my': <gensim.models.keyedvectors.Vocab at 0x7f100ca8dbe0>,
#  'crap': <gensim.models.keyedvectors.Vocab at 0x7f100ca8dc18>,
#  'so': <gensim.models.keyedvectors.Vocab at 0x7f100ca8dc50>,
#  'absurd': <gensim.models.keyedvectors.Vocab at 0x7f100ca8dc88>,
#  'mixing': <gensim.models.keyedvectors.Vocab at 0x7f100ca8dcc0>,
#  'thriller': <gensim.models.keyedvectors.Vocab at 0x7f100ca8dcf8>,
#  'crime': <gensim.models.keyedvectors.Vocab at 0x7f100ca8dd30>,
#  'supernatural': <gensim.models.keyedvectors.Vocab at 0x7f100ca8dd68>,
#  'horror': <gensim.models.keyedvectors.Vocab at 0x7f100ca8dda0>,
#  'even': <gensim.models.keyedvectors.Vocab at 0x7f100ca8ddd8>,
#  'non': <gensim.models.keyedvectors.Vocab at 0x7f100ca8de10>,
#  'sense': <gensim.models.keyedvectors.Vocab at 0x7f100ca8de48>,
#  'way': <gensim.models.keyedvectors.Vocab at 0x7f100ca8de80>,
#  'worst': <gensim.models.keyedvectors.Vocab at 0x7f100ca8deb8>,
#  'possible': <gensim.models.keyedvectors.Vocab at 0x7f100ca8def0>,
#  'highlighting': <gensim.models.keyedvectors.Vocab at 0x7f100ca8df28>,
#  'horrible': <gensim.models.keyedvectors.Vocab at 0
,
#  'cat': <gensim.models.keyedvectors.Vocab at 0x7f100ca94668>,
#  'instances': <gensim.models.keyedvectors.Vocab at 0x7f100ca946a0>,
#  'whatever': <gensim.models.keyedvectors.Vocab at 0x7f100ca946d8>,
#  'circumstances': <gensim.models.keyedvectors.Vocab at 0x7f100ca94710>,
#  'live': <gensim.models.keyedvectors.Vocab at 0x7f100ca94748>,
#  'broadcasts': <gensim.models.keyedvectors.Vocab at 0x7f100ca94780>,
#  'from': <gensim.models.keyedvectors.Vocab at 0x7f100ca947b8>,
#  'th': <gensim.models.keyedvectors.Vocab at 0x7f100ca947f0>,
#  'floor': <gensim.models.keyedvectors.Vocab at 0x7f100ca94828>,
#  'tower': <gensim.models.keyedvectors.Vocab at 0x7f100ca94860>,
#  'block': <gensim.models.keyedvectors.Vocab at 0x7f100ca94898>,
#  'cars': <gensim.models.keyedvectors.Vocab at 0x7f100ca948d0>,
#  'carry': <gensim.models.keyedvectors.Vocab at 0x7f100ca94908>,
#  'leads': <gensim.models.keyedvectors.Vocab at 0x7f100ca94940>,
#  'long': <gensim.models.keyedvectors.Vocab at 0x7f100ca94978>,
#  'enough': <gensim.models.keyedvectors.Vocab at 0x7f100ca949b0>,
#  'connect': <gensim.models.keyedvectors.Vocab at 0x7f100ca949e8>,
#  'microphone': <gensim.models.keyedvectors.Vocab at 0x7f100ca94a20>,
#  'headphones': <gensim.models.keyedvectors.Vocab at 0x7f100ca94a58>,
#  'transmitter': <gensim.models.keyedvectors.Vocab at 0x7f100ca94a90>,
#  'stuck': <gensim.models.keyedvectors.Vocab at 0x7f100ca94ac8>,
#  'lift': <gensim.models.keyedvectors.Vocab at 0x7f100ca94b00>,
#  'scene': <gensim.models.keyedvectors.Vocab at 0x7f100ca94b38>,
#  'utterly': <gensim.models.keyedvectors.Vocab at 0x7f100ca94b70>,
#  'derivative': <gensim.models.keyedvectors.Vocab at 0x7f100ca94ba8>,
#  'almost': <gensim.models.keyedvectors.Vocab at 0x7f100ca94be0>,
#  'existent': <gensim.models.keyedvectors.Vocab at 0x7f100ca94c18>,
#  'could': <gensim.models.keyedvectors.Vocab at 0x7f100ca94c50>,
#  'won': <gensim.models.keyedvectors.Vocab at 0x7f100ca94c88>,
#  'yes': <gensim.models.keyedvectors.Vocab at 0x7f100ca94cc0>,
#  'agree': <gensim.models.keyedvectors.Vocab at 0x7f100ca94cf8>,
#  'everyone': <gensim.models.keyedvectors.Vocab at 0x7f100ca94d30>,
#  'site': <gensim.models.keyedvectors.Vocab at 0x7f100ca94d68>,
#  'call': <gensim.models.keyedvectors.Vocab at 0x7f100ca94da0>,
#  'insult': <gensim.models.keyedvectors.Vocab at 0x7f100ca94dd8>,
#  'movies': <gensim.models.keyedvectors.Vocab at 0x7f100ca94e10>,
#  'compares': <gensim.models.keyedvectors.Vocab at 0x7f100ca94e48>,
#  'b': <gensim.models.keyedvectors.Vocab at 0x7f100ca94e80>,
#  'n': <gensim.models.keyedvectors.Vocab at 0x7f100ca94eb8>,
#  'g': <gensim.models.keyedvectors.Vocab at 0x7f100ca94ef0>,
#  'describes': <gensim.models.keyedvectors.Vocab at 0x7f100ca94f28>,
#  'perfectly': <gensim.models.keyedvectors.Vocab at 0x7f100ca94f60>,
#  'packaging': <gensim.models.keyedvectors.Vocab at 0x7f100ca94f98>,
#  'intentionally': <gensim.models.keyedvectors.Vocab at 0x7f100ca94fd0>,
#  'misleading': <gensim.models.keyedvectors.Vocab at 0x7f100ca96048>,
#  'example': <gensim.models.keyedvectors.Vocab at 0x7f100ca96080>,
#  'should': <gensim.models.keyedvectors.Vocab at 0x7f100ca960b8>,
#  'describe': <gensim.models.keyedvectors.Vocab at 0x7f100ca960f0>,
#  'hint': <gensim.models.keyedvectors.Vocab at 0x7f100ca96128>,
#  'retitled': <gensim.models.keyedvectors.Vocab at 0x7f100ca96160>,
#  'package': <gensim.models.keyedvectors.Vocab at 0x7f100ca96198>,
#  'goofy': <gensim.models.keyedvectors.Vocab at 0x7f100ca961d0>,
#  'face': <gensim.models.keyedvectors.Vocab at 0x7f100ca96208>,
#  'jim': <gensim.models.keyedvectors.Vocab at 0x7f100ca96240>,
#  'probably': <gensim.models.keyedvectors.Vocab at 0x7f100ca96278>,
#  'stand': <gensim.models.keyedvectors.Vocab at 0x7f100ca962b0>,
#  'days': <gensim.models.keyedvectors.Vocab at 0x7f100ca962e8>,
#  'hoping': <gensim.models.keyedvectors.Vocab at 0x7f100ca96320>,
#  'now': <gensim.models.keyedvectors.Vocab at 0x7f100ca96358>,
#  'actor': <gensim.models.keyedvectors.Vocab at 0x7f100ca96390>,
#  'love': <gensim.models.keyedvectors.Vocab at 0x7f100ca963c8>,
#  'him': <gensim.models.keyedvectors.Vocab at 0x7f100ca96400>,
#  'locate': <gensim.models.keyedvectors.Vocab at 0x7f100ca96438>,
#  'rodney': <gensim.models.keyedvectors.Vocab at 0x7f100ca96470>,
#  'dangerfield': <gensim.models.keyedvectors.Vocab at 0x7f100ca964a8>,
#  'comedians': <gensim.models.keyedvectors.Vocab at 0x7f100ca964e0>,
#  'hbo': <gensim.models.keyedvectors.Vocab at 0x7f100ca96518>,
#  'featured': <gensim.models.keyedvectors.Vocab at 0x7f100ca96550>,
#  'early': <gensim.models.keyedvectors.Vocab at 0x7f100ca96588>,
#  'career': <gensim.models.keyedvectors.Vocab at 0x7f100ca965c0>,
#  'isn': <gensim.models.keyedvectors.Vocab at 0x7f100ca965f8>,
#  'mentioned': <gensim.models.keyedvectors.Vocab at 0x7f100ca96630>,
#  'd': <gensim.models.keyedvectors.Vocab at 0x7f100ca96668>,
#  'find': <gensim.models.keyedvectors.Vocab at 0x7f100ca966a0>,
#  'anything': <gensim.models.keyedvectors.Vocab at 0x7f100ca966d8>,
#  'wise': <gensim.models.keyedvectors.Vocab at 0x7f100ca96710>,
#  'also': <gensim.models.keyedvectors.Vocab at 0x7f100ca96748>,
#  'carrey': <gensim.models.keyedvectors.Vocab at 0x7f100ca96780>,
#  'supporting': <gensim.models.keyedvectors.Vocab at 0x7f100ca967b8>,
#  'main': <gensim.models.keyedvectors.Vocab at 0x7f100ca967f0>,
#  'annoying': <gensim.models.keyedvectors.Vocab at 0x7f100ca96828>,
#  'girl': <gensim.models.keyedvectors.Vocab at 0x7f100ca96860>,
#  'lacking': <gensim.models.keyedvectors.Vocab at 0x7f100ca96898>,
#  'self': <gensim.models.keyedvectors.Vocab at 0x7f100ca968d0>,
#  'confidence': <gensim.models.keyedvectors.Vocab at 0x7f100ca96908>,
#  'yet': <gensim.models.keyedvectors.Vocab at 0x7f100ca96940>,
#  'wants': <gensim.models.keyedvectors.Vocab at 0x7f100ca96978>,
#  'comedian': <gensim.models.keyedvectors.Vocab at 0x7f100ca969b0>,
#  'say': <gensim.models.keyedvectors.Vocab at 0x7f100ca969e8>,
#  'lines': <gensim.models.keyedvectors.Vocab at 0x7f100ca96a20>,
#  'funny': <gensim.models.keyedvectors.Vocab at 0x7f100ca96a58>,
#  'janet': <gensim.models.keyedvectors.Vocab at 0x7f100ca96a90>,
#  'talented': <gensim.models.keyedvectors.Vocab at 0x7f100ca96ac8>,
#  'honestly': <gensim.models.keyedvectors.Vocab at 0x7f100ca96b00>,
#  'terrible': <gensim.models.keyedvectors.Vocab at 0x7f100ca96b38>,
#  'beware': <gensim.models.keyedvectors.Vocab at 0x7f100ca96b70>,
#  'false': <gensim.models.keyedvectors.Vocab at 0x7f100ca96ba8>,
#  'advertising': <gensim.models.keyedvectors.Vocab at 0x7f100ca96be0>,
#  'jennifer': <gensim.models.keyedvectors.Vocab at 0x7f100ca96c18>,
#  'ehle': <gensim.models.keyedvectors.Vocab at 0x7f100ca96c50>,
#  'sparkling': <gensim.models.keyedvectors.Vocab at 0x7f100ca96c88>,
#  'pride': <gensim.models.keyedvectors.Vocab at 0x7f100ca96cc0>,
#  'prejudice': <gensim.models.keyedvectors.Vocab at 0x7f100ca96cf8>,
#  'jeremy': <gensim.models.keyedvectors.Vocab at 0x7f100ca96d30>,
#  'northam': <gensim.models.keyedvectors.Vocab at 0x7f100ca96d68>,
#  'simply': <gensim.models.keyedvectors.Vocab at 0x7f100ca96da0>,
#  'wonderful': <gensim.models.keyedvectors.Vocab at 0x7f100ca96dd8>,
#  'boy': <gensim.models.keyedvectors.Vocab at 0x7f100ca96e10>,
#  'actors': <gensim.models.keyedvectors.Vocab at 0x7f100ca96e48>,
#  'caliber': <gensim.models.keyedvectors.Vocab at 0x7f100ca96e80>,
#  'lot': <gensim.models.keyedvectors.Vocab at 0x7f100ca96eb8>,
#  'going': <gensim.models.keyedvectors.Vocab at 0x7f100ca96ef0>,
#  'those': <gensim.models.keyedvectors.Vocab at 0x7f100ca96f28>,
#  'critical': <gensim.models.keyedvectors.Vocab at 0x7f100ca96f60>,
#  'spoke': <gensim.models.keyedvectors.Vocab at 0x7f100ca96f98>,
#  'sequences': <gensim.models.keyedvectors.Vocab at 0x7f100ca96fd0>,
#  'involving': <gensim.models.keyedvectors.Vocab at 0x7f100ca9a048>,
#  'these': <gensim.models.keyedvectors.Vocab at 0x7f100ca9a080>,
#  'eager': <gensim.models.keyedvectors.Vocab at 0x7f100ca9a0b8>,
#  'bitter': <gensim.models.keyedvectors.Vocab at 0x7f100ca9a0f0>,
#  'disappointment': <gensim.models.keyedvectors.Vocab at 0x7f100ca9a128>,
#  'however': <gensim.models.keyedvectors.Vocab at 0x7f100ca9a160>,
#  'must': <gensim.models.keyedvectors.Vocab at 0x7f100ca9a198>,
#  'report': <gensim.models.keyedvectors.Vocab at 0x7f100ca9a1d0>,
#  'flick': <gensim.models.keyedvectors.Vocab at 0x7f100ca9a208>,
#  'piece': <gensim.models.keyedvectors.Vocab at 0x7f100ca9a240>,
#  'scenes': <gensim.models.keyedvectors.Vocab at 0x7f100ca9a278>,
#  'between': <gensim.models.keyedvectors.Vocab at 0x7f100ca9a2b0>,
#  'no': <gensim.models.keyedvectors.Vocab at 0x7f100ca9a2e8>,
#  'depth': <gensim.models.keyedvectors.Vocab at 0x7f100ca9a320>,
#  'tenderness': <gensim.models.keyedvectors.Vocab at 0x7f100ca9a358>,
#  'real': <gensim.models.keyedvectors.Vocab at 0x7f100ca9a390>,
#  'passion': <gensim.models.keyedvectors.Vocab at 0x7f100ca9a3c8>,
#  'consisted': <gensim.models.keyedvectors.Vocab at 0x7f100ca9a400>,
#  'hackneyed': <gensim.models.keyedvectors.Vocab at 0x7f100ca9a438>,
#  'unsubtle': <gensim.models.keyedvectors.Vocab at 0x7f100ca9a470>,
#  'latter': <gensim.models.keyedvectors.Vocab at 0x7f100ca9a4a8>,
#  'cinematic': <gensim.models.keyedvectors.Vocab at 0x7f100ca9a4e0>,
#  'lust': <gensim.models.keyedvectors.Vocab at 0x7f100ca9a518>,
#  'voracious': <gensim.models.keyedvectors.Vocab at 0x7f100ca9a550>,
#  'open': <gensim.models.keyedvectors.Vocab at 0x7f100ca9a588>,
#  'mouthed': <gensim.models.keyedvectors.Vocab at 0x7f100ca9a5c0>,
#  'kissing': <gensim.models.keyedvectors.Vocab at 0x7f100ca9a5f8>,
#  'soft': <gensim.models.keyedvectors.Vocab at 0x7f100ca9a630>,
#  'porn': <gensim.models.keyedvectors.Vocab at 0x7f100ca9a668>,
#  'humping': <gensim.models.keyedvectors.Vocab at 0x7f100ca9a6a0>,
#  'entertaining': <gensim.models.keyedvectors.Vocab at 0x7f100ca9a6d8>,
#  'done': <gensim.models.keyedvectors.Vocab at 0x7f100ca9a710>,
#  'originality': <gensim.models.keyedvectors.Vocab at 0x7f100ca9a748>,
#  'tasteless': <gensim.models.keyedvectors.Vocab at 0x7f100ca9a780>,
#  'awful': <gensim.models.keyedvectors.Vocab at 0x7f100ca9a7b8>,
#  'their': <gensim.models.keyedvectors.Vocab at 0x7f100ca9a7f0>,
#  'craft': <gensim.models.keyedvectors.Vocab at 0x7f100ca9a828>,
#  'ashamed': <gensim.models.keyedvectors.Vocab at 0x7f100ca9a860>,
#  'modern': <gensim.models.keyedvectors.Vocab at 0x7f100ca9a898>,
#  'part': <gensim.models.keyedvectors.Vocab at 0x7f100ca9a8d0>,
#  'romance': <gensim.models.keyedvectors.Vocab at 0x7f100ca9a908>,
#  'effeminate': <gensim.models.keyedvectors.Vocab at 0x7f100ca9a940>,
#  'appearance': <gensim.models.keyedvectors.Vocab at 0x7f100ca9a978>,
#  'male': <gensim.models.keyedvectors.Vocab at 0x7f100ca9a9b0>,
#  'lead': <gensim.models.keyedvectors.Vocab at 0x7f100ca9a9e8>,
#  'aren': <gensim.models.keyedvectors.Vocab at 0x7f100ca9aa20>,
#  'any': <gensim.models.keyedvectors.Vocab at 0x7f100ca9aa58>,
#  'masculine': <gensim.models.keyedvectors.Vocab at 0x7f100ca9aa90>,
#  'men': <gensim.models.keyedvectors.Vocab at 0x7f100ca9aac8>,
#  'left': <gensim.models.keyedvectors.Vocab at 0x7f100ca9ab00>,
#  'hollywood': <gensim.models.keyedvectors.Vocab at 0x7f100ca9ab38>,
#  'plot': <gensim.models.keyedvectors.Vocab at 0x7f100ca9ab70>,
#  'kind': <gensim.models.keyedvectors.Vocab at 0x7f100ca9aba8>,
#  'interesting': <gensim.models.keyedvectors.Vocab at 0x7f100ca9abe0>,
#  'better': <gensim.models.keyedvectors.Vocab at 0x7f100ca9ac18>,
#  'imaginative': <gensim.models.keyedvectors.Vocab at 0x7f100ca9ac50>,
#  'might': <gensim.models.keyedvectors.Vocab at 0x7f100ca9ac88>,
#  'worked': <gensim.models.keyedvectors.Vocab at 0x7f100ca9acc0>,
#  'amy': <gensim.models.keyedvectors.Vocab at 0x7f100ca9acf8>,
#  'terrific': <gensim.models.keyedvectors.Vocab at 0x7f100ca9ad30>,
#  'saturday': <gensim.models.keyedvectors.Vocab at 0x7f100ca9ad68>,
#  'night': <gensim.models.keyedvectors.Vocab at 0x7f100ca9ada0>,
#  'role': <gensim.models.keyedvectors.Vocab at 0x7f100ca9add8>,
#  'give': <gensim.models.keyedvectors.Vocab at 0x7f100ca9ae10>,
#  'work': <gensim.models.keyedvectors.Vocab at 0x7f100ca9ae48>,
#  'publisher': <gensim.models.keyedvectors.Vocab at 0x7f100ca9ae80>,
#  'representative': <gensim.models.keyedvectors.Vocab at 0x7f100ca9aeb8>,
#  'guiding': <gensim.models.keyedvectors.Vocab at 0x7f100ca9aef0>,
#  'author': <gensim.models.keyedvectors.Vocab at 0x7f100ca9af28>,
#  'book': <gensim.models.keyedvectors.Vocab at 0x7f100ca9af60>,
#  'tour': <gensim.models.keyedvectors.Vocab at 0x7f100ca9af98>,
#  'mean': <gensim.models.keyedvectors.Vocab at 0x7f100ca9afd0>,
#  'susan': <gensim.models.keyedvectors.Vocab at 0x7f100ca9e048>,
#  'sarandon': <gensim.models.keyedvectors.Vocab at 0x7f100ca9e080>,
#  'plays': <gensim.models.keyedvectors.Vocab at 0x7f100ca9e0b8>,
#  'mother': <gensim.models.keyedvectors.Vocab at 0x7f100ca9e0f0>,
#  'involved': <gensim.models.keyedvectors.Vocab at 0x7f100ca9e128>,
#  'sadistic': <gensim.models.keyedvectors.Vocab at 0x7f100ca9e160>,
#  'teacher': <gensim.models.keyedvectors.Vocab at 0x7f100ca9e198>,
#  'billy': <gensim.models.keyedvectors.Vocab at 0x7f100ca9e1d0>,
#  'bob': <gensim.models.keyedvectors.Vocab at 0x7f100ca9e208>,
#  'thorton': <gensim.models.keyedvectors.Vocab at 0x7f100ca9e240>,
#  'chubby': <gensim.models.keyedvectors.Vocab at 0x7f100ca9e278>,
#  'junior': <gensim.models.keyedvectors.Vocab at 0x7f100ca9e2b0>,
#  'high': <gensim.models.keyedvectors.Vocab at 0x7f100ca9e2e8>,
#  'student': <gensim.models.keyedvectors.Vocab at 0x7f100ca9e320>,
#  'unfortunately': <gensim.models.keyedvectors.Vocab at 0x7f100ca9e358>,
#  'require': <gensim.models.keyedvectors.Vocab at 0x7f100ca9e390>,
#  'actress': <gensim.models.keyedvectors.Vocab at 0x7f100ca9e3c8>,
#  'funniest': <gensim.models.keyedvectors.Vocab at 0x7f100ca9e400>,
#  'thing': <gensim.models.keyedvectors.Vocab at 0x7f100ca9e438>,
#  'looks': <gensim.models.keyedvectors.Vocab at 0x7f100ca9e470>,
#  'gown': <gensim.models.keyedvectors.Vocab at 0x7f100ca9e4a8>,
#  'wears': <gensim.models.keyedvectors.Vocab at 0x7f100ca9e4e0>,
#  'queen': <gensim.models.keyedvectors.Vocab at 0x7f100ca9e518>,
#  'corn': <gensim.models.keyedvectors.Vocab at 0x7f100ca9e550>,
#  'festival': <gensim.models.keyedvectors.Vocab at 0x7f100ca9e588>,
#  'explanation': <gensim.models.keyedvectors.Vocab at 0x7f100ca9e5c0>,
#  'why': <gensim.models.keyedvectors.Vocab at 0x7f100ca9e5f8>,
#  'old': <gensim.models.keyedvectors.Vocab at 0x7f100ca9e630>,
#  'grown': <gensim.models.keyedvectors.Vocab at 0x7f100ca9e668>,
#  'son': <gensim.models.keyedvectors.Vocab at 0x7f100ca9e6a0>,
#  'stale': <gensim.models.keyedvectors.Vocab at 0x7f100ca9e6d8>,
#  'wrote': <gensim.models.keyedvectors.Vocab at 0x7f100ca9e710>,
#  'best': <gensim.models.keyedvectors.Vocab at 0x7f100ca9e748>,
#  'selling': <gensim.models.keyedvectors.Vocab at 0x7f100ca9e780>,
#  'help': <gensim.models.keyedvectors.Vocab at 0x7f100ca9e7b8>,
#  'then': <gensim.models.keyedvectors.Vocab at 0x7f100ca9e7f0>,
#  'adopts': <gensim.models.keyedvectors.Vocab at 0x7f100ca9e828>,
#  'behavior': <gensim.models.keyedvectors.Vocab at 0x7f100ca9e860>,
#  'contradicts': <gensim.models.keyedvectors.Vocab at 0x7f100ca9e898>,
#  'advice': <gensim.models.keyedvectors.Vocab at 0x7f100ca9e8d0>,
#  've': <gensim.models.keyedvectors.Vocab at 0x7f100ca9e908>,
#  'seen': <gensim.models.keyedvectors.Vocab at 0x7f100ca9e940>,
#  'didn': <gensim.models.keyedvectors.Vocab at 0x7f100ca9e978>,
#  'erase': <gensim.models.keyedvectors.Vocab at 0x7f100ca9e9b0>,
#  'before': <gensim.models.keyedvectors.Vocab at 0x7f100ca9e9e8>,
#  'plane': <gensim.models.keyedvectors.Vocab at 0x7f100ca9ea20>,
#  'carrying': <gensim.models.keyedvectors.Vocab at 0x7f100ca9ea58>,
#  'employees': <gensim.models.keyedvectors.Vocab at 0x7f100ca9ea90>,
#  'large': <gensim.models.keyedvectors.Vocab at 0x7f100ca9eac8>,
#  'firm': <gensim.models.keyedvectors.Vocab at 0x7f100ca9eb00>,
#  'including': <gensim.models.keyedvectors.Vocab at 0x7f100ca9eb38>,
#  'ceo': <gensim.models.keyedvectors.Vocab at 0x7f100ca9eb70>,
#  'daughter': <gensim.models.keyedvectors.Vocab at 0x7f100ca9eba8>,
#  'goes': <gensim.models.keyedvectors.Vocab at 0x7f100ca9ebe0>,
#  'down': <gensim.models.keyedvectors.Vocab at 0x7f100ca9ec18>,
#  'thick': <gensim.models.keyedvectors.Vocab at 0x7f100ca9ec50>,
#  'forest': <gensim.models.keyedvectors.Vocab at 0x7f100ca9ec88>,
#  'pacific': <gensim.models.keyedvectors.Vocab at 0x7f100ca9ecc0>,
#  'northwest': <gensim.models.keyedvectors.Vocab at 0x7f100ca9ecf8>,
#  'search': <gensim.models.keyedvectors.Vocab at 0x7f100ca9ed30>,
#  'rescue': <gensim.models.keyedvectors.Vocab at 0x7f100ca9ed68>,
#  'mission': <gensim.models.keyedvectors.Vocab at 0x7f100ca9eda0>,
#  'called': <gensim.models.keyedvectors.Vocab at 0x7f100ca9edd8>,
#  'off': <gensim.models.keyedvectors.Vocab at 0x7f100ca9ee10>,
#  'harlan': <gensim.models.keyedvectors.Vocab at 0x7f100ca9ee48>,
#  'knowles': <gensim.models.keyedvectors.Vocab at 0x7f100ca9ee80>,
#  'lance': <gensim.models.keyedvectors.Vocab at 0x7f100ca9eeb8>,
#  'henriksen': <gensim.models.keyedvectors.Vocab at 0x7f100ca9eef0>,
#  'puts': <gensim.models.keyedvectors.Vocab at 0x7f100ca9ef28>,
#  'small': <gensim.models.keyedvectors.Vocab at 0x7f100ca9ef60>,
#  'ragtag': <gensim.models.keyedvectors.Vocab at 0x7f100ca9ef98>,
#  'group': <gensim.models.keyedvectors.Vocab at 0x7f100ca9efd0>,
#  'execute': <gensim.models.keyedvectors.Vocab at 0x7f100caa1048>,
#  'own': <gensim.models.keyedvectors.Vocab at 0x7f100caa1080>,
#  'following': <gensim.models.keyedvectors.Vocab at 0x7f100caa10b8>,
#  'woods': <gensim.models.keyedvectors.Vocab at 0x7f100caa10f0>,
#  'oy': <gensim.models.keyedvectors.Vocab at 0x7f100caa1128>,
#  'mess': <gensim.models.keyedvectors.Vocab at 0x7f100caa1160>,
#  'shame': <gensim.models.keyedvectors.Vocab at 0x7f100caa1198>,
#  'stars': <gensim.models.keyedvectors.Vocab at 0x7f100caa11d0>,
#  'favorite': <gensim.models.keyedvectors.Vocab at 0x7f100caa1208>,
#  'genre': <gensim.models.keyedvectors.Vocab at 0x7f100caa1240>,
#  'easily': <gensim.models.keyedvectors.Vocab at 0x7f100caa1278>,
#  'been': <gensim.models.keyedvectors.Vocab at 0x7f100caa12b0>,
#  'decent': <gensim.models.keyedvectors.Vocab at 0x7f100caa12e8>,
#  'suffers': <gensim.models.keyedvectors.Vocab at 0x7f100caa1320>,
#  'major': <gensim.models.keyedvectors.Vocab at 0x7f100caa1358>,
#  'flaws': <gensim.models.keyedvectors.Vocab at 0x7f100caa1390>,
#  're': <gensim.models.keyedvectors.Vocab at 0x7f100caa13c8>,
#  'both': <gensim.models.keyedvectors.Vocab at 0x7f100caa1400>,
#  'writer': <gensim.models.keyedvectors.Vocab at 0x7f100caa1438>,
#  'jonas': <gensim.models.keyedvectors.Vocab at 0x7f100caa1470>,
#  'fault': <gensim.models.keyedvectors.Vocab at 0x7f100caa14a8>,
#  'which': <gensim.models.keyedvectors.Vocab at 0x7f100caa14e0>,
#  'll': <gensim.models.keyedvectors.Vocab at 0x7f100caa1518>,
#  'calling': <gensim.models.keyedvectors.Vocab at 0x7f100caa1550>,
#  'its': <gensim.models.keyedvectors.Vocab at 0x7f100caa1588>,
#  'aka': <gensim.models.keyedvectors.Vocab at 0x7f100caa15c0>,
#  'sasquatch': <gensim.models.keyedvectors.Vocab at 0x7f100caa15f8>,
#  'has': <gensim.models.keyedvectors.Vocab at 0x7f100caa1630>,
#  'editing': <gensim.models.keyedvectors.Vocab at 0x7f100caa1668>,
#  'next': <gensim.models.keyedvectors.Vocab at 0x7f100caa16a0>,
#  'alone': <gensim.models.keyedvectors.Vocab at 0x7f100caa16d8>,
#  'dark': <gensim.models.keyedvectors.Vocab at 0x7f100caa1710>,
#  'constant': <gensim.models.keyedvectors.Vocab at 0x7f100caa1748>,
#  'cast': <gensim.models.keyedvectors.Vocab at 0x7f100caa1780>,
#  'appears': <gensim.models.keyedvectors.Vocab at 0x7f100caa17b8>,
#  'okay': <gensim.models.keyedvectors.Vocab at 0x7f100caa17f0>,
#  'try': <gensim.models.keyedvectors.Vocab at 0x7f100caa1828>,
#  'want': <gensim.models.keyedvectors.Vocab at 0x7f100caa1860>,
#  'top': <gensim.models.keyedvectors.Vocab at 0x7f100caa1898>,
#  'improvise': <gensim.models.keyedvectors.Vocab at 0x7f100caa18d0>,
#  'sequiturs': <gensim.models.keyedvectors.Vocab at 0x7f100caa1908>,
#  'generally': <gensim.models.keyedvectors.Vocab at 0x7f100caa1940>,
#  'potential': <gensim.models.keyedvectors.Vocab at 0x7f100caa1978>,
#  'despite': <gensim.models.keyedvectors.Vocab at 0x7f100caa19b0>,
#  'rip': <gensim.models.keyedvectors.Vocab at 0x7f100caa19e8>,
#  'aspects': <gensim.models.keyedvectors.Vocab at 0x7f100caa1a20>,
#  'material': <gensim.models.keyedvectors.Vocab at 0x7f100caa1a58>,
#  'related': <gensim.models.keyedvectors.Vocab at 0x7f100caa1a90>,
#  'crash': <gensim.models.keyedvectors.Vocab at 0x7f100caa1ac8>,
#  'obviously': <gensim.models.keyedvectors.Vocab at 0x7f100caa1b00>,
#  'crib': <gensim.models.keyedvectors.Vocab at 0x7f100caa1b38>,
#  'blair': <gensim.models.keyedvectors.Vocab at 0x7f100caa1b70>,
#  'witch': <gensim.models.keyedvectors.Vocab at 0x7f100caa1ba8>,
#  'project': <gensim.models.keyedvectors.Vocab at 0x7f100caa1be0>,
#  'titular': <gensim.models.keyedvectors.Vocab at 0x7f100caa1c18>,
#  'monster': <gensim.models.keyedvectors.Vocab at 0x7f100caa1c50>,
#  'predator': <gensim.models.keyedvectors.Vocab at 0x7f100caa1c88>,
#  'ed': <gensim.models.keyedvectors.Vocab at 0x7f100caa1cc0>,
#  'wood': <gensim.models.keyedvectors.Vocab at 0x7f100caa1cf8>,
#  'exposition': <gensim.models.keyedvectors.Vocab at 0x7f100caa1d30>,
#  'dialogue': <gensim.models.keyedvectors.Vocab at 0x7f100caa1d68>,
#  'promise': <gensim.models.keyedvectors.Vocab at 0x7f100caa1da0>,
#  'subtler': <gensim.models.keyedvectors.Vocab at 0x7f100caa1dd8>,
#  'far': <gensim.models.keyedvectors.Vocab at 0x7f100caa1e10>,
#  'saccharine': <gensim.models.keyedvectors.Vocab at 0x7f100caa1e48>,
#  'subtexts': <gensim.models.keyedvectors.Vocab at 0x7f100caa1e80>,
#  'costume': <gensim.models.keyedvectors.Vocab at 0x7f100caa1eb8>,
#  'we': <gensim.models.keyedvectors.Vocab at 0x7f100caa1ef0>,
#  'actually': <gensim.models.keyedvectors.Vocab at 0x7f100caa1f28>,
#  'sufficient': <gensim.models.keyedvectors.Vocab at 0x7f100caa1f60>,
#  'tastes': <gensim.models.keyedvectors.Vocab at 0x7f100caa1f98>,
#  'mixture': <gensim.models.keyedvectors.Vocab at 0x7f100caa1fd0>,
#  'types': <gensim.models.keyedvectors.Vocab at 0x7f100caa5048>,
#  'trudging': <gensim.models.keyedvectors.Vocab at 0x7f100caa5080>,
#  'through': <gensim.models.keyedvectors.Vocab at 0x7f100caa50b8>,
#  'fellow': <gensim.models.keyedvectors.Vocab at 0x7f100caa50f0>,
#  'chris': <gensim.models.keyedvectors.Vocab at 0x7f100caa5128>,
#  'turned': <gensim.models.keyedvectors.Vocab at 0x7f100caa5160>,
#  'stereotype': <gensim.models.keyedvectors.Vocab at 0x7f100caa5198>,
#  'notch': <gensim.models.keyedvectors.Vocab at 0x7f100caa51d0>,
#  'least': <gensim.models.keyedvectors.Vocab at 0x7f100caa5208>,
#  'spent': <gensim.models.keyedvectors.Vocab at 0x7f100caa5240>,
#  'exploring': <gensim.models.keyedvectors.Vocab at 0x7f100caa5278>,
#  'relationships': <gensim.models.keyedvectors.Vocab at 0x7f100caa52b0>,
#  'lair': <gensim.models.keyedvectors.Vocab at 0x7f100caa52e8>,
#  'nice': <gensim.models.keyedvectors.Vocab at 0x7f100caa5320>,
#  'production': <gensim.models.keyedvectors.Vocab at 0x7f100caa5358>,
#  'design': <gensim.models.keyedvectors.Vocab at 0x7f100caa5390>,
#  'specifically': <gensim.models.keyedvectors.Vocab at 0x7f100caa53c8>,
#  'corpse': <gensim.models.keyedvectors.Vocab at 0x7f100caa5400>,
#  'decorations': <gensim.models.keyedvectors.Vocab at 0x7f100caa5438>,
#  'ala': <gensim.models.keyedvectors.Vocab at 0x7f100caa5470>,
#  'primitive': <gensim.models.keyedvectors.Vocab at 0x7f100caa54a8>,
#  'jeepers': <gensim.models.keyedvectors.Vocab at 0x7f100caa54e0>,
#  'creepers': <gensim.models.keyedvectors.Vocab at 0x7f100caa5518>,
#  'edited': <gensim.models.keyedvectors.Vocab at 0x7f100caa5550>,
#  'well': <gensim.models.keyedvectors.Vocab at 0x7f100caa5588>,
#  'effective': <gensim.models.keyedvectors.Vocab at 0x7f100caa55c0>,
#  'most': <gensim.models.keyedvectors.Vocab at 0x7f100caa55f8>,
#  'frightening': <gensim.models.keyedvectors.Vocab at 0x7f100caa5630>,
#  'number': <gensim.models.keyedvectors.Vocab at 0x7f100caa5668>,
#  'missteps': <gensim.models.keyedvectors.Vocab at 0x7f100caa56a0>,
#  'reason': <gensim.models.keyedvectors.Vocab at 0x7f100caa56d8>,
#  'thinks': <gensim.models.keyedvectors.Vocab at 0x7f100caa5710>,
#  'idea': <gensim.models.keyedvectors.Vocab at 0x7f100caa5748>,
#  'chop': <gensim.models.keyedvectors.Vocab at 0x7f100caa5780>,
#  'occur': <gensim.models.keyedvectors.Vocab at 0x7f100caa57b8>,
#  'within': <gensim.models.keyedvectors.Vocab at 0x7f100caa57f0>,
#  'instead': <gensim.models.keyedvectors.Vocab at 0x7f100caa5828>,
#  'few': <gensim.models.keyedvectors.Vocab at 0x7f100caa5860>,
#  'use': <gensim.models.keyedvectors.Vocab at 0x7f100caa5898>,
#  'frequently': <gensim.models.keyedvectors.Vocab at 0x7f100caa58d0>,
#  'screens': <gensim.models.keyedvectors.Vocab at 0x7f100caa5908>,
#  'snippets': <gensim.models.keyedvectors.Vocab at 0x7f100caa5940>,
#  'whether': <gensim.models.keyedvectors.Vocab at 0x7f100caa5978>,
#  'need': <gensim.models.keyedvectors.Vocab at 0x7f100caa59b0>,
#  'unspecified': <gensim.models.keyedvectors.Vocab at 0x7f100caa59e8>,
#  'amount': <gensim.models.keyedvectors.Vocab at 0x7f100caa5a20>,
#  'passing': <gensim.models.keyedvectors.Vocab at 0x7f100caa5a58>,
#  'irrelevant': <gensim.models.keyedvectors.Vocab at 0x7f100caa5a90>,
#  'comments': <gensim.models.keyedvectors.Vocab at 0x7f100caa5ac8>,
#  'seem': <gensim.models.keyedvectors.Vocab at 0x7f100caa5b00>,
#  'occurring': <gensim.models.keyedvectors.Vocab at 0x7f100caa5b38>,
#  'anyway': <gensim.models.keyedvectors.Vocab at 0x7f100caa5b70>,
#  'care': <gensim.models.keyedvectors.Vocab at 0x7f100caa5ba8>,
#  'during': <gensim.models.keyedvectors.Vocab at 0x7f100caa5be0>,
#  'morning': <gensim.models.keyedvectors.Vocab at 0x7f100caa5c18>,
#  'afternoon': <gensim.models.keyedvectors.Vocab at 0x7f100caa5c50>,
#  'middle': <gensim.models.keyedvectors.Vocab at 0x7f100caa5c88>,
#  'cuts': <gensim.models.keyedvectors.Vocab at 0x7f100caa5cc0>,
#  'random': <gensim.models.keyedvectors.Vocab at 0x7f100caa5cf8>,
#  'matter': <gensim.models.keyedvectors.Vocab at 0x7f100caa5d30>,
#  'shown': <gensim.models.keyedvectors.Vocab at 0x7f100caa5d68>,
#  'appear': <gensim.models.keyedvectors.Vocab at 0x7f100caa5da0>,
#  'selected': <gensim.models.keyedvectors.Vocab at 0x7f100caa5dd8>,
#  'important': <gensim.models.keyedvectors.Vocab at 0x7f100caa5e10>,
#  'either': <gensim.models.keyedvectors.Vocab at 0x7f100caa5e48>,
#  'never': <gensim.models.keyedvectors.Vocab at 0x7f100caa5e80>,
#  'barely': <gensim.models.keyedvectors.Vocab at 0x7f100caa5eb8>,
#  'too': <gensim.models.keyedvectors.Vocab at 0x7f100caa5ef0>,
#  'pointless': <gensim.models.keyedvectors.Vocab at 0x7f100caa5f28>,
#  'cave': <gensim.models.keyedvectors.Vocab at 0x7f100caa5f60>,
#  'art': <gensim.models.keyedvectors.Vocab at 0x7f100caa5f98>,
#  'needs': <gensim.models.keyedvectors.Vocab at 0x7f100caa5fd0>,
#  'justify': <gensim.models.keyedvectors.Vocab at 0x7f100ca28048>,
#  'getting': <gensim.models.keyedvectors.Vocab at 0x7f100ca28080>,
#  'intelligence': <gensim.models.keyedvectors.Vocab at 0x7f100ca280b8>,
#  'humanity': <gensim.models.keyedvectors.Vocab at 0x7f100ca280f0>,
#  'whole': <gensim.models.keyedvectors.Vocab at 0x7f100ca28128>,
#  'mary': <gensim.models.keyedvectors.Vocab at 0x7f100ca28160>,
#  'mancini': <gensim.models.keyedvectors.Vocab at 0x7f100ca28198>,
#  'though': <gensim.models.keyedvectors.Vocab at 0x7f100ca281d0>,
#  'superfluous': <gensim.models.keyedvectors.Vocab at 0x7f100ca28208>,
#  'suddenly': <gensim.models.keyedvectors.Vocab at 0x7f100ca28240>,
#  'extremely': <gensim.models.keyedvectors.Vocab at 0x7f100ca28278>,
#  'core': <gensim.models.keyedvectors.Vocab at 0x7f100ca282b0>,
#  'porno': <gensim.models.keyedvectors.Vocab at 0x7f100ca282e8>,
#  'motif': <gensim.models.keyedvectors.Vocab at 0x7f100ca28320>,
#  'repeated': <gensim.models.keyedvectors.Vocab at 0x7f100ca28358>,
#  'characters': <gensim.models.keyedvectors.Vocab at 0x7f100ca28390>,
#  'keep': <gensim.models.keyedvectors.Vocab at 0x7f100ca283c8>,
#  'mr': <gensim.models.keyedvectors.Vocab at 0x7f100ca28400>,
#  'h': <gensim.models.keyedvectors.Vocab at 0x7f100ca28438>,
#  'stereotypes': <gensim.models.keyedvectors.Vocab at 0x7f100ca28470>,
#  'asian': <gensim.models.keyedvectors.Vocab at 0x7f100ca284a8>,
#  'insists': <gensim.models.keyedvectors.Vocab at 0x7f100ca284e0>,
#  'using': <gensim.models.keyedvectors.Vocab at 0x7f100ca28518>,
#  'blurry': <gensim.models.keyedvectors.Vocab at 0x7f100ca28550>,
#  'cam': <gensim.models.keyedvectors.Vocab at 0x7f100ca28588>,
#  'attack': <gensim.models.keyedvectors.Vocab at 0x7f100ca285c0>,
#  'look': <gensim.models.keyedvectors.Vocab at 0x7f100ca285f8>,
# ...
#  'every': <gensim.models.keyedvectors.Vocab at 0x7f100ca289b0>,
#  'thought': <gensim.models.keyedvectors.Vocab at 0x7f100ca289e8>,
#  'point': <gensim.models.keyedvectors.Vocab at 0x7f100ca28a20>,
#  'until': <gensim.models.keyedvectors.Vocab at 0x7f100ca28a58>,
#  'move': <gensim.models.keyedvectors.Vocab at 0x7f100ca28a90>,
#  'score': <gensim.models.keyedvectors.Vocab at 0x7f100ca28ac8>,
#  'gritty': <gensim.models.keyedvectors.Vocab at 0x7f100ca28b00>,
#  'science': <gensim.models.keyedvectors.Vocab at 0x7f100ca28b38>,
#  'fiction': <gensim.models.keyedvectors.Vocab at 0x7f100ca28b70>,
#  'among': <gensim.models.keyedvectors.Vocab at 0x7f100ca28ba8>,
#  'hundreds': <gensim.models.keyedvectors.Vocab at 0x7f100ca28be0>,
#  'similar': <gensim.models.keyedvectors.Vocab at 0x7f100ca28c18>,
#  'several': <gensim.models.keyedvectors.Vocab at 0x7f100ca28c50>,
#  'strong': <gensim.models.keyedvectors.Vocab at 0x7f100ca28c88>,
#  'points': <gensim.models.keyedvectors.Vocab at 0x7f100ca28cc0>,
#  'near': <gensim.models.keyedvectors.Vocab at 0x7f100ca28cf8>,
#  'writing': <gensim.models.keyedvectors.Vocab at 0x7f100ca28d30>,
#  'directing': <gensim.models.keyedvectors.Vocab at 0x7f100ca28d68>,
#  'solid': <gensim.models.keyedvectors.Vocab at 0x7f100ca28da0>,
#  'manages': <gensim.models.keyedvectors.Vocab at 0x7f100ca28dd8>,
#  'sci': <gensim.models.keyedvectors.Vocab at 0x7f100ca28e10>,
#  'fi': <gensim.models.keyedvectors.Vocab at 0x7f100ca28e48>,
#  'cliches': <gensim.models.keyedvectors.Vocab at 0x7f100ca28e80>,
#  'does': <gensim.models.keyedvectors.Vocab at 0x7f100ca28eb8>,
#  'job': <gensim.models.keyedvectors.Vocab at 0x7f100ca28ef0>,
#  'keeping': <gensim.models.keyedvectors.Vocab at 0x7f100ca28f28>,
#  'suspense': <gensim.models.keyedvectors.Vocab at 0x7f100ca28f60>,
#  'landscape': <gensim.models.keyedvectors.Vocab at 0x7f100ca28f98>,
#  'will': <gensim.models.keyedvectors.Vocab at 0x7f100ca28fd0>,
#  'appeal': <gensim.models.keyedvectors.Vocab at 0x7f100ca2d048>,
#  'fans': <gensim.models.keyedvectors.Vocab at 0x7f100ca2d080>,
#  'looking': <gensim.models.keyedvectors.Vocab at 0x7f100ca2d0b8>,
#  'masterpiece': <gensim.models.keyedvectors.Vocab at 0x7f100ca2d0f0>,
#  'fashioned': <gensim.models.keyedvectors.Vocab at 0x7f100ca2d128>,
#  'post': <gensim.models.keyedvectors.Vocab at 0x7f100ca2d160>,
#  'future': <gensim.models.keyedvectors.Vocab at 0x7f100ca2d198>,
#  'space': <gensim.models.keyedvectors.Vocab at 0x7f100ca2d1d0>,
#  'thoroughly': <gensim.models.keyedvectors.Vocab at 0x7f100ca2d208>,
#  'enjoyable': <gensim.models.keyedvectors.Vocab at 0x7f100ca2d240>,
#  'ending': <gensim.models.keyedvectors.Vocab at 0x7f100ca2d278>,
#  'incredibly': <gensim.models.keyedvectors.Vocab at 0x7f100ca2d2b0>,
#  'dumb': <gensim.models.keyedvectors.Vocab at 0x7f100ca2d2e8>,
#  'predictable': <gensim.models.keyedvectors.Vocab at 0x7f100ca2d320>,
#  'rich': <gensim.models.keyedvectors.Vocab at 0x7f100ca2d358>,
#  'teen': <gensim.models.keyedvectors.Vocab at 0x7f100ca2d390>,
#  'given': <gensim.models.keyedvectors.Vocab at 0x7f100ca2d3c8>,
#  'parents': <gensim.models.keyedvectors.Vocab at 0x7f100ca2d400>,
#  'gang': <gensim.models.keyedvectors.Vocab at 0x7f100ca2d438>,
#  'rob': <gensim.models.keyedvectors.Vocab at 0x7f100ca2d470>,
#  'gas': <gensim.models.keyedvectors.Vocab at 0x7f100ca2d4a8>,
#  'stations': <gensim.models.keyedvectors.Vocab at 0x7f100ca2d4e0>,
#  'rape': <gensim.models.keyedvectors.Vocab at 0x7f100ca2d518>,
#  'guys': <gensim.models.keyedvectors.Vocab at 0x7f100ca2d550>,
#  'kill': <gensim.models.keyedvectors.Vocab at 0x7f100ca2d588>,
#  'policeman': <gensim.models.keyedvectors.Vocab at 0x7f100ca2d5c0>,
#  'teenagers': <gensim.models.keyedvectors.Vocab at 0x7f100ca2d5f8>,
#  'late': <gensim.models.keyedvectors.Vocab at 0x7f100ca2d630>,
#  'cliche': <gensim.models.keyedvectors.Vocab at 0x7f100ca2d668>,
#  'imaginable': <gensim.models.keyedvectors.Vocab at 0x7f100ca2d6a0>,
#  'hilarious': <gensim.models.keyedvectors.Vocab at 0x7f100ca2d6d8>,
#  'surprise': <gensim.models.keyedvectors.Vocab at 0x7f100ca2d710>,
#  'written': <gensim.models.keyedvectors.Vocab at 0x7f100ca2d748>,
#  'immortal': <gensim.models.keyedvectors.Vocab at 0x7f100ca2d780>,
#  'jr': <gensim.models.keyedvectors.Vocab at 0x7f100ca2d7b8>,
#  'worth': <gensim.models.keyedvectors.Vocab at 0x7f100ca2d7f0>,
#  'laughs': <gensim.models.keyedvectors.Vocab at 0x7f100ca2d828>,
#  'shooting': <gensim.models.keyedvectors.Vocab at 0x7f100ca2d860>,
#  'ain': <gensim.models.keyedvectors.Vocab at 0x7f100ca2d898>,
#  'supposed': <gensim.models.keyedvectors.Vocab at 0x7f100ca2d8d0>,
#  'reading': <gensim.models.keyedvectors.Vocab at 0x7f100ca2d908>,
#  'am': <gensim.models.keyedvectors.Vocab at 0x7f100ca2d940>,
#  'sure': <gensim.models.keyedvectors.Vocab at 0x7f100ca2d978>,
#  'angry': <gensim.models.keyedvectors.Vocab at 0x7f100ca2d9b0>,
#  'sad': <gensim.models.keyedvectors.Vocab at 0x7f100ca2d9e8>,
#  'sickened': <gensim.models.keyedvectors.Vocab at 0x7f100ca2da20>,
#  'typical': <gensim.models.keyedvectors.Vocab at 0x7f100ca2da58>,
#  'know': <gensim.models.keyedvectors.Vocab at 0x7f100ca2da90>,
#  'absolutely': <gensim.models.keyedvectors.Vocab at 0x7f100ca2dac8>,
#  'military': <gensim.models.keyedvectors.Vocab at 0x7f100ca2db00>,
#  'base': <gensim.models.keyedvectors.Vocab at 0x7f100ca2db38>,
#  'everything': <gensim.models.keyedvectors.Vocab at 0x7f100ca2db70>,
#  'cnn': <gensim.models.keyedvectors.Vocab at 0x7f100ca2dba8>,
#  'reports': <gensim.models.keyedvectors.Vocab at 0x7f100ca2dbe0>,
#  'abu': <gensim.models.keyedvectors.Vocab at 0x7f100ca2dc18>,
#  'makes': <gensim.models.keyedvectors.Vocab at 0x7f100ca2dc50>,
#  'me': <gensim.models.keyedvectors.Vocab at 0x7f100ca2dc88>,
#  'wonder': <gensim.models.keyedvectors.Vocab at 0x7f100ca2dcc0>,
#  'state': <gensim.models.keyedvectors.Vocab at 0x7f100ca2dcf8>,
#  'intellectual': <gensim.models.keyedvectors.Vocab at 0x7f100ca2dd30>,
#  'stimulation': <gensim.models.keyedvectors.Vocab at 0x7f100ca2dd68>,
#  'world': <gensim.models.keyedvectors.Vocab at 0x7f100ca2dda0>,
#  'type': <gensim.models.keyedvectors.Vocab at 0x7f100ca2ddd8>,
#  'us': <gensim.models.keyedvectors.Vocab at 0x7f100ca2de10>,
#  'million': <gensim.models.keyedvectors.Vocab at 0x7f100ca2de48>,
#  'active': <gensim.models.keyedvectors.Vocab at 0x7f100ca2de80>,
#  'duty': <gensim.models.keyedvectors.Vocab at 0x7f100ca2deb8>,
#  'guard': <gensim.models.keyedvectors.Vocab at 0x7f100ca2def0>,
#  'reserves': <gensim.models.keyedvectors.Vocab at 0x7f100ca2df28>,
#  'total': <gensim.models.keyedvectors.Vocab at 0x7f100ca2df60>,
#  'roughly': <gensim.models.keyedvectors.Vocab at 0x7f100ca2df98>,
#  'abuses': <gensim.models.keyedvectors.Vocab at 0x7f100ca2dfd0>,
#  'currently': <gensim.models.keyedvectors.Vocab at 0x7f100ca2f048>,
#  'single': <gensim.models.keyedvectors.Vocab at 0x7f100ca2f080>,
#  'member': <gensim.models.keyedvectors.Vocab at 0x7f100ca2f0b8>,
#  'stepped': <gensim.models.keyedvectors.Vocab at 0x7f100ca2f0f0>,
#  'come': <gensim.models.keyedvectors.Vocab at 0x7f100ca2f128>,
#  'close': <gensim.models.keyedvectors.Vocab at 0x7f100ca2f160>,
#  'take': <gensim.models.keyedvectors.Vocab at 0x7f100ca2f198>,
#  'understand': <gensim.models.keyedvectors.Vocab at 0x7f100ca2f1d0>,
#  'sarcastic': <gensim.models.keyedvectors.Vocab at 0x7f100ca2f208>,
#  'reality': <gensim.models.keyedvectors.Vocab at 0x7f100ca2f240>,
#  'commentary': <gensim.models.keyedvectors.Vocab at 0x7f100ca2f278>,
#  'without': <gensim.models.keyedvectors.Vocab at 0x7f100ca2f2b0>,
#  'enemy': <gensim.models.keyedvectors.Vocab at 0x7f100ca2f2e8>,
#  'fight': <gensim.models.keyedvectors.Vocab at 0x7f100ca2f320>,
#  'conflicts': <gensim.models.keyedvectors.Vocab at 0x7f100ca2f358>,
#  'disaster': <gensim.models.keyedvectors.Vocab at 0x7f100ca2f390>,
#  'relief': <gensim.models.keyedvectors.Vocab at 0x7f100ca2f3c8>,
#  'humanitarian': <gensim.models.keyedvectors.Vocab at 0x7f100ca2f400>,
#  'aid': <gensim.models.keyedvectors.Vocab at 0x7f100ca2f438>,
#  'missions': <gensim.models.keyedvectors.Vocab at 0x7f100ca2f470>,
#  'hit': <gensim.models.keyedvectors.Vocab at 0x7f100ca2f4a8>,
#  'indonesia': <gensim.models.keyedvectors.Vocab at 0x7f100ca2f4e0>,
#  'region': <gensim.models.keyedvectors.Vocab at 0x7f100ca2f518>,
#  'chaos': <gensim.models.keyedvectors.Vocab at 0x7f100ca2f550>,
#  'situation': <gensim.models.keyedvectors.Vocab at 0x7f100ca2f588>,
#  'overwhelmed': <gensim.models.keyedvectors.Vocab at 0x7f100ca2f5c0>,
#  'governments': <gensim.models.keyedvectors.Vocab at 0x7f100ca2f5f8>,
#  'leadership': <gensim.models.keyedvectors.Vocab at 0x7f100ca2f630>,
#  'looked': <gensim.models.keyedvectors.Vocab at 0x7f100ca2f668>,
#  'same': <gensim.models.keyedvectors.Vocab at 0x7f100ca2f6a0>,
#  'mocks': <gensim.models.keyedvectors.Vocab at 0x7f100ca2f6d8>,
#  'happen': <gensim.models.keyedvectors.Vocab at 0x7f100ca2f710>,
#  'food': <gensim.models.keyedvectors.Vocab at 0x7f100ca2f748>,
#  'reaching': <gensim.models.keyedvectors.Vocab at 0x7f100ca2f780>,
#  'isolated': <gensim.models.keyedvectors.Vocab at 0x7f100ca2f7b8>,
#  'villages': <gensim.models.keyedvectors.Vocab at 0x7f100ca2f7f0>,
#  'built': <gensim.models.keyedvectors.Vocab at 0x7f100ca2f828>,
#  'cargo': <gensim.models.keyedvectors.Vocab at 0x7f100ca2f860>,
#  'aircraft': <gensim.models.keyedvectors.Vocab at 0x7f100ca2f898>,
#  'started': <gensim.models.keyedvectors.Vocab at 0x7f100ca2f8d0>,
#  'landing': <gensim.models.keyedvectors.Vocab at 0x7f100ca2f908>,
#  'distribution': <gensim.models.keyedvectors.Vocab at 0x7f100ca2f940>,
#  'system': <gensim.models.keyedvectors.Vocab at 0x7f100ca2f978>,
#  'running': <gensim.models.keyedvectors.Vocab at 0x7f100ca2f9b0>,
#  'weeks': <gensim.models.keyedvectors.Vocab at 0x7f100ca2f9e8>,
#  'months': <gensim.models.keyedvectors.Vocab at 0x7f100ca2fa20>,
#  'unscrupulous': <gensim.models.keyedvectors.Vocab at 0x7f100ca2fa58>,
#  'walk': <gensim.models.keyedvectors.Vocab at 0x7f100ca2fa90>,
#  'occupation': <gensim.models.keyedvectors.Vocab at 0x7f100ca2fac8>,
#  'website': <gensim.models.keyedvectors.Vocab at 0x7f100ca2fb00>,
#  'criminal': <gensim.models.keyedvectors.Vocab at 0x7f100ca2fb38>,
#  'minds': <gensim.models.keyedvectors.Vocab at 0x7f100ca2fb70>,
#  'thoughts': <gensim.models.keyedvectors.Vocab at 0x7f100ca2fba8>,
#  'destruction': <gensim.models.keyedvectors.Vocab at 0x7f100ca2fbe0>,
#  'mayhem': <gensim.models.keyedvectors.Vocab at 0x7f100ca2fc18>,
#  'absolute': <gensim.models.keyedvectors.Vocab at 0x7f100ca2fc50>,
#  'disservice': <gensim.models.keyedvectors.Vocab at 0x7f100ca2fc88>,
#  'things': <gensim.models.keyedvectors.Vocab at 0x7f100ca2fcc0>,
#  'person': <gensim.models.keyedvectors.Vocab at 0x7f100ca2fcf8>,
#  'members': <gensim.models.keyedvectors.Vocab at 0x7f100ca2fd30>,
#  'personal': <gensim.models.keyedvectors.Vocab at 0x7f100ca2fd68>,
#  'gain': <gensim.models.keyedvectors.Vocab at 0x7f100ca2fda0>,
#  'wow': <gensim.models.keyedvectors.Vocab at 0x7f100ca2fdd8>,
#  'entry': <gensim.models.keyedvectors.Vocab at 0x7f100ca2fe10>,
#  'personnel': <gensim.models.keyedvectors.Vocab at 0x7f100ca2fe48>,
#  'under': <gensim.models.keyedvectors.Vocab at 0x7f100ca2fe80>,
#  'hour': <gensim.models.keyedvectors.Vocab at 0x7f100ca2feb8>,
#  'assuming': <gensim.models.keyedvectors.Vocab at 0x7f100ca2fef0>,
#  'week': <gensim.models.keyedvectors.Vocab at 0x7f100ca2ff28>,
#  'course': <gensim.models.keyedvectors.Vocab at 0x7f100ca2ff60>,
#  'harm': <gensim.models.keyedvectors.Vocab at 0x7f100ca2ff98>,
#  'typically': <gensim.models.keyedvectors.Vocab at 0x7f100ca2ffd0>,
#  'pay': <gensim.models.keyedvectors.Vocab at 0x7f100ca33048>,
#  'minimum': <gensim.models.keyedvectors.Vocab at 0x7f100ca33080>,
#  'wage': <gensim.models.keyedvectors.Vocab at 0x7f100ca330b8>,
#  'beg': <gensim.models.keyedvectors.Vocab at 0x7f100ca330f0>,
#  'please': <gensim.models.keyedvectors.Vocab at 0x7f100ca33128>,
#  'yourself': <gensim.models.keyedvectors.Vocab at 0x7f100ca33160>,
#  'familiar': <gensim.models.keyedvectors.Vocab at 0x7f100ca33198>,
#  'nearby': <gensim.models.keyedvectors.Vocab at 0x7f100ca331d0>,
#  'visitor': <gensim.models.keyedvectors.Vocab at 0x7f100ca33208>,
#  'pass': <gensim.models.keyedvectors.Vocab at 0x7f100ca33240>,
#  'meet': <gensim.models.keyedvectors.Vocab at 0x7f100ca33278>,
#  'quick': <gensim.models.keyedvectors.Vocab at 0x7f100ca332b0>,
#  'surprised': <gensim.models.keyedvectors.Vocab at 0x7f100ca332e8>,
#  'longer': <gensim.models.keyedvectors.Vocab at 0x7f100ca33320>,
#  'accepts': <gensim.models.keyedvectors.Vocab at 0x7f100ca33358>,
#  'lieu': <gensim.models.keyedvectors.Vocab at 0x7f100ca33390>,
#  'prison': <gensim.models.keyedvectors.Vocab at 0x7f100ca333c8>,
#  'ged': <gensim.models.keyedvectors.Vocab at 0x7f100ca33400>,
#  'prefer': <gensim.models.keyedvectors.Vocab at 0x7f100ca33438>,
#  'ranks': <gensim.models.keyedvectors.Vocab at 0x7f100ca33470>,
#  'expected': <gensim.models.keyedvectors.Vocab at 0x7f100ca334a8>,
#  'undergraduate': <gensim.models.keyedvectors.Vocab at 0x7f100ca334e0>,
#  'degrees': <gensim.models.keyedvectors.Vocab at 0x7f100ca33518>,
#  'upper': <gensim.models.keyedvectors.Vocab at 0x7f100ca33550>,
#  'encouraged': <gensim.models.keyedvectors.Vocab at 0x7f100ca33588>,
#  'advanced': <gensim.models.keyedvectors.Vocab at 0x7f100ca335c0>,
#  'hard': <gensim.models.keyedvectors.Vocab at 0x7f100ca335f8>,
#  'elfen': <gensim.models.keyedvectors.Vocab at 0x7f100ca33630>,
#  'lied': <gensim.models.keyedvectors.Vocab at 0x7f100ca33668>,
#  'hasn': <gensim.models.keyedvectors.Vocab at 0x7f100ca336a0>,
#  'heard': <gensim.models.keyedvectors.Vocab at 0x7f100ca336d8>,
#  'closest': <gensim.models.keyedvectors.Vocab at 0x7f100ca33710>,
#  'strange': <gensim.models.keyedvectors.Vocab at 0x7f100ca33748>,
#  'mix': <gensim.models.keyedvectors.Vocab at 0x7f100ca33780>,
#  'extreme': <gensim.models.keyedvectors.Vocab at 0x7f100ca337b8>,
#  'violence': <gensim.models.keyedvectors.Vocab at 0x7f100ca337f0>,
#  'drama': <gensim.models.keyedvectors.Vocab at 0x7f100ca33828>,
#  'haven': <gensim.models.keyedvectors.Vocab at 0x7f100ca33860>,
#  'witnessed': <gensim.models.keyedvectors.Vocab at 0x7f100ca33898>,
#  'wondering': <gensim.models.keyedvectors.Vocab at 0x7f100ca338d0>,
#  'how': <gensim.models.keyedvectors.Vocab at 0x7f100ca33908>,
#  'incorporated': <gensim.models.keyedvectors.Vocab at 0x7f100ca33940>,
#  'coherently': <gensim.models.keyedvectors.Vocab at 0x7f100ca33978>,
#  'pondering': <gensim.models.keyedvectors.Vocab at 0x7f100ca339b0>,
#  'sooner': <gensim.models.keyedvectors.Vocab at 0x7f100ca339e8>,
#  'such': <gensim.models.keyedvectors.Vocab at 0x7f100ca33a20>,
#  'quality': <gensim.models.keyedvectors.Vocab at 0x7f100ca33a58>,
#  'flow': <gensim.models.keyedvectors.Vocab at 0x7f100ca33a90>,
#  'odd': <gensim.models.keyedvectors.Vocab at 0x7f100ca33ac8>,
#  'hybrid': <gensim.models.keyedvectors.Vocab at 0x7f100ca33b00>,
#  'anime': <gensim.models.keyedvectors.Vocab at 0x7f100ca33b38>,
#  'area': <gensim.models.keyedvectors.Vocab at 0x7f100ca33b70>,
#  'shines': <gensim.models.keyedvectors.Vocab at 0x7f100ca33ba8>,
#  'narrative': <gensim.models.keyedvectors.Vocab at 0x7f100ca33be0>,
#  'enthralled': <gensim.models.keyedvectors.Vocab at 0x7f100ca33c18>,
#  'weaving': <gensim.models.keyedvectors.Vocab at 0x7f100ca33c50>,
#  'diversity': <gensim.models.keyedvectors.Vocab at 0x7f100ca33c88>,
#  'violent': <gensim.models.keyedvectors.Vocab at 0x7f100ca33cc0>,
#  'gory': <gensim.models.keyedvectors.Vocab at 0x7f100ca33cf8>,
#  'encounter': <gensim.models.keyedvectors.Vocab at 0x7f100ca33d30>,
#  'perhaps': <gensim.models.keyedvectors.Vocab at 0x7f100ca33d68>,
#  'contrasting': <gensim.models.keyedvectors.Vocab at 0x7f100ca33da0>,
#  'lighter': <gensim.models.keyedvectors.Vocab at 0x7f100ca33dd8>,
#  'moment': <gensim.models.keyedvectors.Vocab at 0x7f100ca33e10>,
#  'emotive': <gensim.models.keyedvectors.Vocab at 0x7f100ca33e48>,
#  'bloodshed': <gensim.models.keyedvectors.Vocab at 0x7f100ca33e80>,
#  'bring': <gensim.models.keyedvectors.Vocab at 0x7f100ca33eb8>,
#  'tears': <gensim.models.keyedvectors.Vocab at 0x7f100ca33ef0>,
#  'combination': <gensim.models.keyedvectors.Vocab at 0x7f100ca33f28>,
#  'where': <gensim.models.keyedvectors.Vocab at 0x7f100ca33f60>,
#  'viewer': <gensim.models.keyedvectors.Vocab at 0x7f100ca33f98>,
#  ...}

# %% [markdown]
# ### Get an embedding for a word

# %%
model.wv['flower']
# Out:
# array([-0.6986385 , -1.1521771 , -0.38489717, -0.20228364, -0.44553578,
#        -0.00937   , -0.16896184, -0.57302314, -0.28248858, -0.37187326,
#         1.7044677 , -0.26498455,  0.7375803 , -0.18606572, -0.46843514,
#         0.15523411,  0.18438125,  0.986107  ,  0.11671095,  0.09187862,
#        -0.7966294 , -0.46644554,  0.33725765, -2.2658787 ,  0.21272008,
#         0.05462522,  1.0833925 , -1.0689386 ,  0.09475855,  0.6652133 ,
#         0.45978713, -0.6511303 , -0.778628  ,  1.2860738 ,  0.28800553,
#         0.39701656, -0.663345  ,  1.4186627 ,  0.9362171 ,  0.01667313,
#        -0.6179613 ,  0.3351227 , -0.02626111, -0.7527745 ,  0.31824034,
#         0.58760625,  0.3418974 , -0.49677905, -0.18857573, -1.2116163 ],
#       dtype=float32)

# %% [markdown]
# ### Finding Words which have similar meaning

# %%
model.wv.most_similar('great')
# Out:
# 2019-12-07 00:50:19,402 : INFO : precomputing L2-norms of word weight vectors
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('fantastic', 0.8884958028793335),
#  ('terrific', 0.8786453008651733),
#  ('wonderful', 0.8739440441131592),
#  ('fine', 0.8313859105110168),
#  ('good', 0.8302212953567505),
#  ('brilliant', 0.8095049858093262),
#  ('superb', 0.7917463183403015),
#  ('perfect', 0.7840341925621033),
#  ('nice', 0.7647720575332642),
#  ('fabulous', 0.7349982857704163)]

# %% [markdown]
# ### Find the word which is not like others

# %%
model.doesnt_match("man woman child kitchen".split())
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `doesnt_match` (Method will be removed in 4.0.0, use self.wv.doesnt_match() instead).
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/gensim/models/keyedvectors.py:895: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   vectors = vstack(self.word_vec(word, use_norm=True) for word in used_words).astype(REAL)
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# 'kitchen'

# %% [markdown]
# ### Saving the model

# %%
model.save('word2vec-movie-50')
# Out:
# 2019-12-07 00:52:00,362 : INFO : saving Word2Vec object under word2vec-movie-50, separately None
# 2019-12-07 00:52:00,364 : INFO : not storing attribute vectors_norm
# 2019-12-07 00:52:00,368 : INFO : not storing attribute cum_table
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:402: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# 2019-12-07 00:52:00,593 : INFO : saved word2vec-movie-50

# %%
#Load model from memory
model = gensim.models.Word2Vec.load('word2vec-movie-50')
# Out:
# 2019-12-07 00:52:05,128 : INFO : loading Word2Vec object from word2vec-movie-50
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:402: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# 2019-12-07 00:52:05,285 : INFO : loading wv recursively from word2vec-movie-50.wv.* with mmap=None
# 2019-12-07 00:52:05,287 : INFO : setting ignored attribute vectors_norm to None
# 2019-12-07 00:52:05,289 : INFO : loading vocabulary recursively from word2vec-movie-50.vocabulary.* with mmap=None
# 2019-12-07 00:52:05,291 : INFO : loading trainables recursively from word2vec-movie-50.trainables.* with mmap=None
# 2019-12-07 00:52:05,292 : INFO : setting ignored attribute cum_table to None
# 2019-12-07 00:52:05,293 : INFO : loaded word2vec-movie-50

# %% [markdown]
# 1. Equation king + man = queen + ?
# 2. In this case there may not be enough data for this equation

# %%
model.most_similar(positive=['king','man'], negative=['queen'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# 2019-12-07 00:52:17,677 : INFO : precomputing L2-norms of word weight vectors
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('scientist', 0.5845720767974854),
#  ('joker', 0.5635032057762146),
#  ('mastermind', 0.5621315240859985),
#  ('toulon', 0.5580616593360901),
#  ('hector', 0.5526635050773621),
#  ('puppet', 0.5492327213287354),
#  ('master', 0.5439491271972656),
#  ('warlord', 0.5411689281463623),
#  ('shimura', 0.537550151348114),
#  ('buio', 0.5331234335899353)]

# %%
model.wv['king'] + model.wv['man'] - model.wv['queen']
# Out:
# array([-4.0110874 ,  3.1203845 , -1.4800844 ,  0.96598756, -0.35236132,
#         3.0539253 , -5.279897  ,  0.85881996, -0.4635051 , -0.09170306,
#        -2.176845  ,  6.954863  ,  3.7289171 , -1.4919454 ,  1.7240916 ,
#         2.4132953 , -0.11126602,  2.6064959 ,  0.49891257, -4.3038836 ,
#        -0.8722282 ,  1.2754617 , -2.9492958 , -1.9411099 ,  1.5082257 ,
#         0.9865351 ,  0.0898366 , -2.7046409 ,  1.2646043 ,  4.4898133 ,
#         1.2258763 ,  0.96033   , -5.4216685 ,  3.1572387 ,  0.5975101 ,
#         1.2290099 ,  1.6515203 , -2.2924511 , -3.153595  ,  3.18757   ,
#         2.6550794 ,  2.1473522 , -3.9034522 , -2.3374574 , -3.5272598 ,
#        -2.0754042 , -2.6888778 ,  0.65288734,  2.8974347 , -1.7383344 ],
#       dtype=float32)
